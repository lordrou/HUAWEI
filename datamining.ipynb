# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
# Out:
# /anaconda3/envs/anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
pd.set_option('display.max_columns',None)

# %%
#读取数据
age_train = pd.read_csv("age_train.csv", names=['uid','age_group'])
age_test = pd.read_csv("age_test.csv", names=['uid'])
user_basic_info = pd.read_csv("user_basic_info.csv", names=['uid','gender','city','prodName','ramCapacity','ramLeftRation','romCapacity','romLeftRation','color','fontSize','ct','carrier','os'])
user_behavior_info = pd.read_csv("user_behavior_info.csv", names=['uid','bootTimes','AFuncTimes','BFuncTimes','CFuncTimes','DFuncTimes','EFuncTimes','FFuncTimes','FFuncSum'])
user_app_actived = pd.read_csv("user_app_actived.csv", names=['uid','appId'])
#user_app_usage = pd.read_csv("user_app_usage.csv")
app_info = pd.read_csv("app_info.csv", names=['appId', 'category'])

# %%
#处理数据量较大的user_app_usage.csv，结合app_info.csv简单统计得到appuseProcessed.csv作为特征
def f(x):
    s = x.value_counts()
    return np.nan if len(s) == 0 else s.index[0]
def processUserAppUsage():
    resTable = pd.DataFrame()
    reader = pd.read_csv("user_app_usage.csv", names=['uid','appId','duration','times','use_date'], iterator=True)
    last_df = pd.DataFrame()
    
    app_info = pd.read_csv("app_info.csv", names=['appId','category'])
    cats = list(set(app_info['category']))
    category2id = dict(zip(sorted(cats), range(0,len(cats))))
    id2category = dict(zip(range(0,len(cats)), sorted(cats)))
    app_info['category'] = app_info['category'].apply(lambda x: category2id[x])
    i = 1
    
    while True:
        try:
            print("index: {}".format(i))
            i+=1
            df = reader.get_chunk(1000000)
            df = pd.concat([last_df, df])
            idx = df.shape[0]-1
            last_user = df.iat[idx,0]
            while(df.iat[idx,0]==last_user):
                idx-=1
            last_df = df[idx+1:]
            df = df[:idx+1]

            now_df = pd.DataFrame()
            now_df['uid'] = df['uid'].unique()
            now_df = now_df.merge(df.groupby('uid')['appId'].count().to_frame(), how='left', on='uid')
            now_df = now_df.merge(df.groupby('uid')['appId','use_date'].agg(['nunique']), how='left', on='uid')
            now_df = now_df.merge(df.groupby('uid')['duration','times'].agg(['mean','max','std']), how='left', on='uid')    

            now_df.columns = ['uid','usage_cnt','usage_appid_cnt','usage_date_cnt','duration_mean','duration_max','duration_std','times_mean','times_max','times_std']


            df = df.merge(app_info, how='left', on='appId')
            now_df = now_df.merge(df.groupby('uid')['category'].nunique().to_frame(), how='left', on='uid')
            #print(df.groupby(['uid'])['category'].value_counts().index[0])
            now_df['usage_most_used_category'] = df.groupby(['uid'])['category'].transform(f)
            resTable = pd.concat([resTable, now_df])
        except StopIteration:
            break
    
    resTable.to_csv("appuseProcessed.csv",index=0)
    
    print("Iterator is stopped")

# %%
processUserAppUsage()
# Out:
# index: 1
# /anaconda3/envs/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py:544: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# index: 2
# index: 3
# index: 4
# index: 5
# index: 6
# index: 7
# index: 8
# index: 9
# index: 10
# index: 11
# index: 12
# index: 13
# index: 14
# index: 15
# index: 16
# index: 17
# index: 18
# index: 19
# index: 20
# index: 21
# index: 22
# index: 23
# index: 24
# index: 25
# index: 26
# index: 27
# index: 28
# index: 29
# index: 30
# index: 31
# index: 32
# index: 33
# index: 34
# index: 35
# index: 36
# index: 37
# index: 38
# index: 39
# index: 40
# index: 41
# index: 42
# index: 43
# index: 44
# index: 45
# index: 46
# index: 47
# index: 48
# index: 49
# index: 50
# index: 51
# index: 52
# index: 53
# index: 54
# index: 55
# index: 56
# index: 57
# index: 58
# index: 59
# index: 60
# index: 61
# index: 62
# index: 63
# index: 64
# index: 65
# index: 66
# index: 67
# index: 68
# index: 69
# index: 70
# index: 71
# index: 72
# index: 73
# index: 74
# index: 75
# index: 76
# index: 77
# index: 78
# index: 79
# index: 80
# index: 81
# index: 82
# index: 83
# index: 84
# index: 85
# index: 86
# index: 87
# index: 88
# index: 89
# index: 90
# index: 91
# index: 92
# index: 93
# index: 94
# index: 95
# index: 96
# index: 97
# index: 98
# index: 99
# index: 100
# index: 101
# index: 102
# index: 103
# index: 104
# index: 105
# index: 106
# index: 107
# index: 108
# index: 109
# index: 110
# index: 111
# index: 112
# index: 113
# index: 114
# index: 115
# index: 116
# index: 117
# index: 118
# index: 119
# index: 120
# index: 121
# index: 122
# index: 123
# index: 124
# index: 125
# index: 126
# index: 127
# index: 128
# index: 129
# index: 130
# index: 131
# index: 132
# index: 133
# index: 134
# index: 135
# index: 136
# index: 137
# index: 138
# index: 139
# index: 140
# index: 141
# index: 142
# index: 143
# index: 144
# index: 145
# index: 146
# index: 147
# index: 148
# index: 149
# index: 150
# index: 151
# index: 152
# index: 153
# index: 154
# index: 155
# index: 156
# index: 157
# index: 158
# index: 159
# index: 160
# index: 161
# index: 162
# index: 163
# index: 164
# index: 165
# index: 166
# index: 167
# index: 168
# index: 169
# index: 170
# index: 171
# index: 172
# index: 173
# index: 174
# index: 175
# index: 176
# index: 177
# index: 178
# index: 179
# index: 180
# index: 181
# index: 182
# index: 183
# index: 184
# index: 185
# index: 186
# index: 187
# index: 188
# index: 189
# index: 190
# index: 191
# index: 192
# index: 193
# index: 194
# index: 195
# index: 196
# index: 197
# index: 198
# index: 199
# index: 200
# index: 201
# index: 202
# index: 203
# index: 204
# index: 205
# index: 206
# index: 207
# index: 208
# index: 209
# index: 210
# index: 211
# index: 212
# index: 213
# index: 214
# index: 215
# index: 216
# index: 217
# index: 218
# index: 219
# index: 220
# index: 221
# index: 222
# index: 223
# index: 224
# index: 225
# index: 226
# index: 227
# index: 228
# index: 229
# index: 230
# index: 231
# index: 232
# index: 233
# index: 234
# index: 235
# index: 236
# index: 237
# index: 238
# index: 239
# index: 240
# index: 241
# index: 242
# index: 243
# index: 244
# index: 245
# index: 246
# index: 247
# index: 248
# index: 249
# index: 250
# index: 251
# index: 252
# index: 253
# index: 254
# index: 255
# index: 256
# index: 257
# index: 258
# index: 259
# index: 260
# index: 261
# index: 262
# index: 263
# index: 264
# index: 265
# index: 266
# index: 267
# index: 268
# index: 269
# index: 270
# index: 271
# index: 272
# index: 273
# index: 274
# index: 275
# index: 276
# index: 277
# index: 278
# index: 279
# index: 280
# index: 281
# index: 282
# index: 283
# index: 284
# index: 285
# index: 286
# index: 287
# index: 288
# index: 289
# index: 290
# index: 291
# index: 292
# index: 293
# index: 294
# index: 295
# index: 296
# index: 297
# index: 298
# index: 299
# index: 300
# index: 301
# index: 302
# index: 303
# index: 304
# index: 305
# index: 306
# index: 307
# index: 308
# index: 309
# index: 310
# index: 311
# index: 312
# index: 313
# index: 314
# index: 315
# index: 316
# index: 317
# index: 318
# index: 319
# index: 320
# index: 321
# index: 322
# index: 323
# index: 324
# index: 325
# index: 326
# index: 327
# index: 328
# index: 329
# index: 330
# index: 331
# index: 332
# index: 333
# index: 334
# index: 335
# index: 336
# index: 337
# index: 338
# index: 339
# index: 340
# index: 341
# index: 342
# index: 343
# index: 344
# index: 345
# index: 346
# index: 347
# index: 348
# index: 349
# index: 350
# index: 351
# index: 352
# index: 353
# index: 354
# index: 355
# index: 356
# index: 357
# index: 358
# index: 359
# index: 360
# index: 361
# index: 362
# index: 363
# index: 364
# index: 365
# index: 366
# index: 367
# index: 368
# index: 369
# index: 370
# index: 371
# index: 372
# index: 373
# index: 374
# index: 375
# index: 376
# index: 377
# index: 378
# index: 379
# index: 380
# index: 381
# index: 382
# index: 383
# index: 384
# index: 385
# index: 386
# index: 387
# index: 388
# index: 389
# index: 390
# index: 391
# index: 392
# index: 393
# index: 394
# index: 395
# index: 396
# index: 397
# index: 398
# index: 399
# index: 400
# index: 401
# index: 402
# index: 403
# index: 404
# index: 405
# index: 406
# index: 407
# index: 408
# index: 409
# index: 410
# index: 411
# index: 412
# index: 413
# index: 414
# index: 415
# index: 416
# index: 417
# index: 418
# index: 419
# index: 420
# index: 421
# index: 422
# index: 423
# index: 424
# index: 425
# index: 426
# index: 427
# index: 428
# index: 429
# index: 430
# index: 431
# index: 432
# index: 433
# index: 434
# index: 435
# index: 436
# index: 437
# index: 438
# index: 439
# index: 440
# index: 441
# index: 442
# index: 443
# index: 444
# index: 445
# index: 446
# index: 447
# index: 448
# index: 449
# index: 450
# index: 451
# index: 452
# index: 453
# index: 454
# index: 455
# index: 456
# index: 457
# index: 458
# index: 459
# index: 460
# index: 461
# index: 462
# index: 463
# index: 464
# index: 465
# index: 466
# index: 467
# index: 468
# index: 469
# index: 470
# index: 471
# index: 472
# index: 473
# index: 474
# index: 475
# index: 476
# index: 477
# index: 478
# index: 479
# index: 480
# index: 481
# index: 482
# index: 483
# index: 484
# index: 485
# index: 486
# index: 487
# index: 488
# index: 489
# index: 490
# index: 491
# index: 492
# index: 493
# index: 494
# index: 495
# index: 496
# index: 497
# index: 498
# index: 499
# index: 500
# index: 501
# index: 502
# index: 503
# index: 504
# index: 505
# index: 506
# index: 507
# index: 508
# index: 509
# index: 510
# index: 511
# index: 512
# index: 513
# index: 514
# index: 515
# index: 516
# index: 517
# index: 518
# index: 519
# index: 520
# index: 521
# index: 522
# index: 523
# index: 524
# index: 525
# index: 526
# index: 527
# index: 528
# index: 529
# index: 530
# index: 531
# index: 532
# index: 533
# index: 534
# index: 535
# index: 536
# index: 537
# index: 538
# index: 539
# index: 540
# index: 541
# index: 542
# index: 543
# index: 544
# index: 545
# index: 546
# index: 547
# index: 548
# index: 549
# index: 550
# index: 551
# index: 552
# index: 553
# index: 554
# index: 555
# index: 556
# index: 557
# index: 558
# index: 559
# index: 560
# index: 561
# index: 562
# index: 563
# index: 564
# index: 565
# index: 566
# index: 567
# index: 568
# index: 569
# index: 570
# index: 571
# index: 572
# index: 573
# index: 574
# index: 575
# index: 576
# index: 577
# index: 578
# index: 579
# index: 580
# index: 581
# index: 582
# index: 583
# index: 584
# index: 585
# index: 586
# index: 587
# index: 588
# index: 589
# index: 590
# index: 591
# index: 592
# index: 593
# index: 594
# index: 595
# index: 596
# index: 597
# index: 598
# index: 599
# index: 600
# index: 601
# index: 602
# index: 603
# index: 604
# index: 605
# index: 606
# index: 607
# index: 608
# index: 609
# index: 610
# index: 611
# index: 612
# index: 613
# index: 614
# index: 615
# index: 616
# index: 617
# index: 618
# index: 619
# index: 620
# index: 621
# index: 622
# index: 623
# index: 624
# index: 625
# index: 626
# index: 627
# index: 628
# index: 629
# index: 630
# index: 631
# index: 632
# index: 633
# index: 634
# index: 635
# index: 636
# index: 637
# index: 638
# index: 639
# index: 640
# index: 641
# index: 642
# index: 643
# index: 644
# index: 645
# index: 646
# index: 647
# index: 648
# index: 649
# index: 650
# index: 651
# index: 652
# index: 653
# Iterator is stopped

# %%
# 将user_basic_info.csv 和 processed_behavior.csv中的字符值编码成可以训练的数值类型，合并
class2id = {}
id2class = {}
processed_behavior = pd.read_csv("processed_behavior.csv", names=['uid', 'bootTimes', 'AllFuncSum', 'MaxFunc', 'FuncCnt', 'FFuncSum'])
def mergeBasicTables(baseTable):
    resTable = baseTable.merge(user_basic_info, how='left', on='uid', suffixes=('_base0', '_ubaf'))
    resTable = resTable.merge(processed_behavior, how='left', on='uid', suffixes=('_base1', '_ubef'))
    cat_columns = ['city','prodName','color','carrier','os','ct']
    for c in cat_columns:
        resTable[c] = resTable[c].apply(lambda x: x if type(x)==str else str(x))
        sort_temp = sorted(list(set(resTable[c])))  
        class2id[c+'2id'] = dict(zip(sort_temp, range(1, len(sort_temp)+1)))
        id2class['id2'+c] = dict(zip(range(1,len(sort_temp)+1), sort_temp))
        resTable[c] = resTable[c].apply(lambda x: class2id[c+'2id'][x])
        
    return resTable

# %%
# 对user_app_actived.csv简单统计
# 将之前训练的appuseProcess.csv进行合并
def mergeAppData(baseTable):
    resTable = baseTable.merge(user_app_actived, how='left', on='uid')
    resTable['appId'] = resTable['appId'].apply(lambda x: len(list(x.split('#'))))
    appusedTable = pd.read_csv("appuseProcessed.csv")
    resTable = resTable.merge(appusedTable, how='left', on='uid')
    resTable[['category', 'usage_most_used_category']] = resTable[['category', 'usage_most_used_category']].fillna(41)
    resTable = resTable.fillna(0)
    return resTable

# %%
#合并用户基本特征以及app使用相关特征，作为训练集和测试集
df_train = mergeAppData(mergeBasicTables(age_train))
df_test = mergeAppData(mergeBasicTables(age_test))
df_train.to_csv("train_data.csv", index = 0)
print(df_train.shape)
print(df_test.shape)
# Out:
# (2010000, 31)
# (502500, 30)

# %%
#训练模型
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
from sklearn.feature_selection import SelectFromModel, VarianceThreshold, SelectKBest, chi2, mutual_info_classif, f_classif
from sklearn.preprocessing import Imputer
from sklearn.ensemble import ExtraTreesClassifier

import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
from sklearn.model_selection import StratifiedKFold

# %%
print("训练模型：")
param = {
        'learning_rate': 0.08,
        'lambda_l1': 0.1,
        'lambda_l2': 0.2,
        'max_depth': 20,
        'objective': 'multiclass',
        'num_class': 7,
        'num_leaves': 31,
        'min_data_in_leaf': 50,
        'max_bin': 230,
        'feature_fraction': 0.8,
        'metric': 'multi_error'
        }

X = df_train.drop(['age_group','uid'], axis=1)
y = df_train['age_group']
uid = df_test['uid']
test = df_test.drop('uid', axis=1)

xx_score = []
cv_pred = []
skf = StratifiedKFold(n_splits=3, random_state=1030, shuffle=True)
for index, (train_index, vali_index) in enumerate(skf.split(X, y)):
    print(index)
    x_train, y_train, x_vali, y_vali = np.array(X)[train_index], np.array(y)[train_index], np.array(X)[vali_index], np.array(y)[vali_index]
    train = lgb.Dataset(x_train, y_train)
    vali =lgb.Dataset(x_vali, y_vali)
    print("training start...")
    model = lgb.train(param, train, num_boost_round=1000, valid_sets=[vali], early_stopping_rounds=50)
    xx_pred = model.predict(x_vali,num_iteration=model.best_iteration)
    xx_pred = [np.argmax(x) for x in xx_pred]
    xx_score.append(f1_score(y_vali,xx_pred,average='weighted'))
    y_test = model.predict(test,num_iteration=model.best_iteration)
    y_test = [np.argmax(x) for x in y_test]
    if index == 0:
        cv_pred = np.array(y_test).reshape(-1, 1)
    else:
        cv_pred = np.hstack((cv_pred, np.array(y_test).reshape(-1, 1)))
        
submit = []
for line in cv_pred:
    submit.append(np.argmax(np.bincount(line)))
df = pd.DataFrame({'id':uid.as_matrix(),'label':submit})
df.to_csv('submission.csv',index=False)
# Out:
# 训练模型：
# 0
# training start...
# [1]	valid_0's multi_error: 0.701493
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's multi_error: 0.701493
# [3]	valid_0's multi_error: 0.701493
# [4]	valid_0's multi_error: 0.696723
# [5]	valid_0's multi_error: 0.690597
# [6]	valid_0's multi_error: 0.682768
# [7]	valid_0's multi_error: 0.675212
# [8]	valid_0's multi_error: 0.66898
# [9]	valid_0's multi_error: 0.662759
# [10]	valid_0's multi_error: 0.656592
# [11]	valid_0's multi_error: 0.650705
# [12]	valid_0's multi_error: 0.645209
# [13]	valid_0's multi_error: 0.640651
# [14]	valid_0's multi_error: 0.636717
# [15]	valid_0's multi_error: 0.63409
# [16]	valid_0's multi_error: 0.631468
# [17]	valid_0's multi_error: 0.628668
# [18]	valid_0's multi_error: 0.626318
# [19]	valid_0's multi_error: 0.623714
# [20]	valid_0's multi_error: 0.622507
# [21]	valid_0's multi_error: 0.620935
# [22]	valid_0's multi_error: 0.61961
# [23]	valid_0's multi_error: 0.618318
# [24]	valid_0's multi_error: 0.617087
# [25]	valid_0's multi_error: 0.616013
# [26]	valid_0's multi_error: 0.614778
# [27]	valid_0's multi_error: 0.613496
# [28]	valid_0's multi_error: 0.612535
# [29]	valid_0's multi_error: 0.611608
# [30]	valid_0's multi_error: 0.610883
# [31]	valid_0's multi_error: 0.609972
# [32]	valid_0's multi_error: 0.609066
# [33]	valid_0's multi_error: 0.608375
# [34]	valid_0's multi_error: 0.607681
# [35]	valid_0's multi_error: 0.606918
# [36]	valid_0's multi_error: 0.606278
# [37]	valid_0's multi_error: 0.605539
# [38]	valid_0's multi_error: 0.604784
# [39]	valid_0's multi_error: 0.60443
# [40]	valid_0's multi_error: 0.60385
# [41]	valid_0's multi_error: 0.603236
# [42]	valid_0's multi_error: 0.602641
# [43]	valid_0's multi_error: 0.602208
# [44]	valid_0's multi_error: 0.601644
# [45]	valid_0's multi_error: 0.601162
# [46]	valid_0's multi_error: 0.600623
# [47]	valid_0's multi_error: 0.600104
# [48]	valid_0's multi_error: 0.599732
# [49]	valid_0's multi_error: 0.599154
# [50]	valid_0's multi_error: 0.59869
# [51]	valid_0's multi_error: 0.59822
# [52]	valid_0's multi_error: 0.597948
# [53]	valid_0's multi_error: 0.597502
# [54]	valid_0's multi_error: 0.597147
# [55]	valid_0's multi_error: 0.596907
# [56]	valid_0's multi_error: 0.596381
# [57]	valid_0's multi_error: 0.595959
# [58]	valid_0's multi_error: 0.595381
# [59]	valid_0's multi_error: 0.595101
# [60]	valid_0's multi_error: 0.594559
# [61]	valid_0's multi_error: 0.59425
# [62]	valid_0's multi_error: 0.594035
# [63]	valid_0's multi_error: 0.593626
# [64]	valid_0's multi_error: 0.593292
# [65]	valid_0's multi_error: 0.593048
# [66]	valid_0's multi_error: 0.592678
# [67]	valid_0's multi_error: 0.592257
# [68]	valid_0's multi_error: 0.591968
# [69]	valid_0's multi_error: 0.591692
# [70]	valid_0's multi_error: 0.591493
# [71]	valid_0's multi_error: 0.591059
# [72]	valid_0's multi_error: 0.59082
# [73]	valid_0's multi_error: 0.59053
# [74]	valid_0's multi_error: 0.590144
# [75]	valid_0's multi_error: 0.589947
# [76]	valid_0's multi_error: 0.589668
# [77]	valid_0's multi_error: 0.589319
# [78]	valid_0's multi_error: 0.588992
# [79]	valid_0's multi_error: 0.588789
# [80]	valid_0's multi_error: 0.588372
# [81]	valid_0's multi_error: 0.588257
# [82]	valid_0's multi_error: 0.587866
# [83]	valid_0's multi_error: 0.587504
# [84]	valid_0's multi_error: 0.587414
# [85]	valid_0's multi_error: 0.587086
# [86]	valid_0's multi_error: 0.586929
# [87]	valid_0's multi_error: 0.586701
# [88]	valid_0's multi_error: 0.586459
# [89]	valid_0's multi_error: 0.586229
# [90]	valid_0's multi_error: 0.586005
# [91]	valid_0's multi_error: 0.585802
# [92]	valid_0's multi_error: 0.585522
# [93]	valid_0's multi_error: 0.585296
# [94]	valid_0's multi_error: 0.58521
# [95]	valid_0's multi_error: 0.584971
# [96]	valid_0's multi_error: 0.584822
# [97]	valid_0's multi_error: 0.584599
# [98]	valid_0's multi_error: 0.584432
# [99]	valid_0's multi_error: 0.584114
# [100]	valid_0's multi_error: 0.584008
# [101]	valid_0's multi_error: 0.583878
# [102]	valid_0's multi_error: 0.58373
# [103]	valid_0's multi_error: 0.583486
# [104]	valid_0's multi_error: 0.583371
# [105]	valid_0's multi_error: 0.583126
# [106]	valid_0's multi_error: 0.582869
# [107]	valid_0's multi_error: 0.58269
# [108]	valid_0's multi_error: 0.582577
# [109]	valid_0's multi_error: 0.582484
# [110]	valid_0's multi_error: 0.582196
# [111]	valid_0's multi_error: 0.58198
# [112]	valid_0's multi_error: 0.581766
# [113]	valid_0's multi_error: 0.58159
# [114]	valid_0's multi_error: 0.581477
# [115]	valid_0's multi_error: 0.581257
# [116]	valid_0's multi_error: 0.581101
# [117]	valid_0's multi_error: 0.581001
# [118]	valid_0's multi_error: 0.580874
# [119]	valid_0's multi_error: 0.580626
# [120]	valid_0's multi_error: 0.580478
# [121]	valid_0's multi_error: 0.580375
# [122]	valid_0's multi_error: 0.580314
# [123]	valid_0's multi_error: 0.580136
# [124]	valid_0's multi_error: 0.580086
# [125]	valid_0's multi_error: 0.579847
# [126]	valid_0's multi_error: 0.579745
# [127]	valid_0's multi_error: 0.579565
# [128]	valid_0's multi_error: 0.57938
# [129]	valid_0's multi_error: 0.579236
# [130]	valid_0's multi_error: 0.579068
# [131]	valid_0's multi_error: 0.578953
# [132]	valid_0's multi_error: 0.578825
# [133]	valid_0's multi_error: 0.578656
# [134]	valid_0's multi_error: 0.578477
# [135]	valid_0's multi_error: 0.578287
# [136]	valid_0's multi_error: 0.578102
# [137]	valid_0's multi_error: 0.578045
# [138]	valid_0's multi_error: 0.577863
# [139]	valid_0's multi_error: 0.577804
# [140]	valid_0's multi_error: 0.577674
# [141]	valid_0's multi_error: 0.577507
# [142]	valid_0's multi_error: 0.577338
# [143]	valid_0's multi_error: 0.577477
# [144]	valid_0's multi_error: 0.577304
# [145]	valid_0's multi_error: 0.57712
# [146]	valid_0's multi_error: 0.577125
# [147]	valid_0's multi_error: 0.577047
# [148]	valid_0's multi_error: 0.576914
# [149]	valid_0's multi_error: 0.576792
# [150]	valid_0's multi_error: 0.576692
# [151]	valid_0's multi_error: 0.576605
# [152]	valid_0's multi_error: 0.576456
# [153]	valid_0's multi_error: 0.576389
# [154]	valid_0's multi_error: 0.576301
# [155]	valid_0's multi_error: 0.576198
# [156]	valid_0's multi_error: 0.576133
# [157]	valid_0's multi_error: 0.57599
# [158]	valid_0's multi_error: 0.575883
# [159]	valid_0's multi_error: 0.575816
# [160]	valid_0's multi_error: 0.575641
# [161]	valid_0's multi_error: 0.575568
# [162]	valid_0's multi_error: 0.575425
# [163]	valid_0's multi_error: 0.575292
# [164]	valid_0's multi_error: 0.575248
# [165]	valid_0's multi_error: 0.575089
# [166]	valid_0's multi_error: 0.574996
# [167]	valid_0's multi_error: 0.574892
# [168]	valid_0's multi_error: 0.574922
# [169]	valid_0's multi_error: 0.574844
# [170]	valid_0's multi_error: 0.574789
# [171]	valid_0's multi_error: 0.574686
# [172]	valid_0's multi_error: 0.574517
# [173]	valid_0's multi_error: 0.574463
# [174]	valid_0's multi_error: 0.574465
# [175]	valid_0's multi_error: 0.574393
# [176]	valid_0's multi_error: 0.574269
# [177]	valid_0's multi_error: 0.574175
# [178]	valid_0's multi_error: 0.574086
# [179]	valid_0's multi_error: 0.573893
# [180]	valid_0's multi_error: 0.57389
# [181]	valid_0's multi_error: 0.573766
# [182]	valid_0's multi_error: 0.573708
# [183]	valid_0's multi_error: 0.573605
# [184]	valid_0's multi_error: 0.573572
# [185]	valid_0's multi_error: 0.573462
# [186]	valid_0's multi_error: 0.573339
# [187]	valid_0's multi_error: 0.57325
# [188]	valid_0's multi_error: 0.57311
# [189]	valid_0's multi_error: 0.573086
# [190]	valid_0's multi_error: 0.57301
# [191]	valid_0's multi_error: 0.572881
# [192]	valid_0's multi_error: 0.572881
# [193]	valid_0's multi_error: 0.57282
# [194]	valid_0's multi_error: 0.572871
# [195]	valid_0's multi_error: 0.572823
# [196]	valid_0's multi_error: 0.572714
# [197]	valid_0's multi_error: 0.572692
# [198]	valid_0's multi_error: 0.572568
# [199]	valid_0's multi_error: 0.572471
# [200]	valid_0's multi_error: 0.572399
# [201]	valid_0's multi_error: 0.572304
# [202]	valid_0's multi_error: 0.572235
# [203]	valid_0's multi_error: 0.572125
# [204]	valid_0's multi_error: 0.572108
# [205]	valid_0's multi_error: 0.572002
# [206]	valid_0's multi_error: 0.571965
# [207]	valid_0's multi_error: 0.571869
# [208]	valid_0's multi_error: 0.571848
# [209]	valid_0's multi_error: 0.571672
# [210]	valid_0's multi_error: 0.571638
# [211]	valid_0's multi_error: 0.571598
# [212]	valid_0's multi_error: 0.571432
# [213]	valid_0's multi_error: 0.571435
# [214]	valid_0's multi_error: 0.571395
# [215]	valid_0's multi_error: 0.571283
# [216]	valid_0's multi_error: 0.571223
# [217]	valid_0's multi_error: 0.571181
# [218]	valid_0's multi_error: 0.571178
# [219]	valid_0's multi_error: 0.57108
# [220]	valid_0's multi_error: 0.571081
# [221]	valid_0's multi_error: 0.57106
# [222]	valid_0's multi_error: 0.570892
# [223]	valid_0's multi_error: 0.57085
# [224]	valid_0's multi_error: 0.570814
# [225]	valid_0's multi_error: 0.570595
# [226]	valid_0's multi_error: 0.570548
# [227]	valid_0's multi_error: 0.570532
# [228]	valid_0's multi_error: 0.570465
# [229]	valid_0's multi_error: 0.570429
# [230]	valid_0's multi_error: 0.570398
# [231]	valid_0's multi_error: 0.570325
# [232]	valid_0's multi_error: 0.570341
# [233]	valid_0's multi_error: 0.570357
# [234]	valid_0's multi_error: 0.570195
# [235]	valid_0's multi_error: 0.570101
# [236]	valid_0's multi_error: 0.570086
# [237]	valid_0's multi_error: 0.570038
# [238]	valid_0's multi_error: 0.570035
# [239]	valid_0's multi_error: 0.569872
# [240]	valid_0's multi_error: 0.569798
# [241]	valid_0's multi_error: 0.56979
# [242]	valid_0's multi_error: 0.569671
# [243]	valid_0's multi_error: 0.569636
# [244]	valid_0's multi_error: 0.569607
# [245]	valid_0's multi_error: 0.569496
# [246]	valid_0's multi_error: 0.569489
# [247]	valid_0's multi_error: 0.569353
# [248]	valid_0's multi_error: 0.569316
# [249]	valid_0's multi_error: 0.56925
# [250]	valid_0's multi_error: 0.569286
# [251]	valid_0's multi_error: 0.569214
# [252]	valid_0's multi_error: 0.569159
# [253]	valid_0's multi_error: 0.569105
# [254]	valid_0's multi_error: 0.569117
# [255]	valid_0's multi_error: 0.569054
# [256]	valid_0's multi_error: 0.568998
# [257]	valid_0's multi_error: 0.568959
# [258]	valid_0's multi_error: 0.568832
# [259]	valid_0's multi_error: 0.568844
# [260]	valid_0's multi_error: 0.56873
# [261]	valid_0's multi_error: 0.568716
# [262]	valid_0's multi_error: 0.568716
# [263]	valid_0's multi_error: 0.568711
# [264]	valid_0's multi_error: 0.56866
# [265]	valid_0's multi_error: 0.568638
# [266]	valid_0's multi_error: 0.568584
# [267]	valid_0's multi_error: 0.568548
# [268]	valid_0's multi_error: 0.568472
# [269]	valid_0's multi_error: 0.568402
# [270]	valid_0's multi_error: 0.568405
# [271]	valid_0's multi_error: 0.568408
# [272]	valid_0's multi_error: 0.568283
# [273]	valid_0's multi_error: 0.568295
# [274]	valid_0's multi_error: 0.568196
# [275]	valid_0's multi_error: 0.568202
# [276]	valid_0's multi_error: 0.568177
# [277]	valid_0's multi_error: 0.568128
# [278]	valid_0's multi_error: 0.568075
# [279]	valid_0's multi_error: 0.568025
# [280]	valid_0's multi_error: 0.567968
# [281]	valid_0's multi_error: 0.567913
# [282]	valid_0's multi_error: 0.567819
# [283]	valid_0's multi_error: 0.567823
# [284]	valid_0's multi_error: 0.567747
# [285]	valid_0's multi_error: 0.567622
# [286]	valid_0's multi_error: 0.567608
# [287]	valid_0's multi_error: 0.567595
# [288]	valid_0's multi_error: 0.567568
# [289]	valid_0's multi_error: 0.567544
# [290]	valid_0's multi_error: 0.567505
# [291]	valid_0's multi_error: 0.567547
# [292]	valid_0's multi_error: 0.567475
# [293]	valid_0's multi_error: 0.567368
# [294]	valid_0's multi_error: 0.567378
# [295]	valid_0's multi_error: 0.567308
# [296]	valid_0's multi_error: 0.567266
# [297]	valid_0's multi_error: 0.567229
# [298]	valid_0's multi_error: 0.567116
# [299]	valid_0's multi_error: 0.56715
# [300]	valid_0's multi_error: 0.567056
# [301]	valid_0's multi_error: 0.566974
# [302]	valid_0's multi_error: 0.56696
# [303]	valid_0's multi_error: 0.566975
# [304]	valid_0's multi_error: 0.566851
# [305]	valid_0's multi_error: 0.56682
# [306]	valid_0's multi_error: 0.566826
# [307]	valid_0's multi_error: 0.566769
# [308]	valid_0's multi_error: 0.566747
# [309]	valid_0's multi_error: 0.566732
# [310]	valid_0's multi_error: 0.566656
# [311]	valid_0's multi_error: 0.566674
# [312]	valid_0's multi_error: 0.566607
# [313]	valid_0's multi_error: 0.566545
# [314]	valid_0's multi_error: 0.566475
# [315]	valid_0's multi_error: 0.566469
# [316]	valid_0's multi_error: 0.566425
# [317]	valid_0's multi_error: 0.566432
# [318]	valid_0's multi_error: 0.566366
# [319]	valid_0's multi_error: 0.566333
# [320]	valid_0's multi_error: 0.566281
# [321]	valid_0's multi_error: 0.566268
# [322]	valid_0's multi_error: 0.566166
# [323]	valid_0's multi_error: 0.566196
# [324]	valid_0's multi_error: 0.566148
# [325]	valid_0's multi_error: 0.566154
# [326]	valid_0's multi_error: 0.566151
# [327]	valid_0's multi_error: 0.566156
# [328]	valid_0's multi_error: 0.566084
# [329]	valid_0's multi_error: 0.56608
# [330]	valid_0's multi_error: 0.566044
# [331]	valid_0's multi_error: 0.565987
# [332]	valid_0's multi_error: 0.565959
# [333]	valid_0's multi_error: 0.566032
# [334]	valid_0's multi_error: 0.565969
# [335]	valid_0's multi_error: 0.565944
# [336]	valid_0's multi_error: 0.565911
# [337]	valid_0's multi_error: 0.565871
# [338]	valid_0's multi_error: 0.565826
# [339]	valid_0's multi_error: 0.565757
# [340]	valid_0's multi_error: 0.565669
# [341]	valid_0's multi_error: 0.565607
# [342]	valid_0's multi_error: 0.565607
# [343]	valid_0's multi_error: 0.56559
# [344]	valid_0's multi_error: 0.565547
# [345]	valid_0's multi_error: 0.565511
# [346]	valid_0's multi_error: 0.565535
# [347]	valid_0's multi_error: 0.565498
# [348]	valid_0's multi_error: 0.565468
# [349]	valid_0's multi_error: 0.565477
# [350]	valid_0's multi_error: 0.565416
# [351]	valid_0's multi_error: 0.565383
# [352]	valid_0's multi_error: 0.565411
# [353]	valid_0's multi_error: 0.565357
# [354]	valid_0's multi_error: 0.565336
# [355]	valid_0's multi_error: 0.565326
# [356]	valid_0's multi_error: 0.565322
# [357]	valid_0's multi_error: 0.565316
# [358]	valid_0's multi_error: 0.565292
# [359]	valid_0's multi_error: 0.565171
# [360]	valid_0's multi_error: 0.565113
# [361]	valid_0's multi_error: 0.565092
# [362]	valid_0's multi_error: 0.565029
# [363]	valid_0's multi_error: 0.565004
# [364]	valid_0's multi_error: 0.565001
# [365]	valid_0's multi_error: 0.564925
# [366]	valid_0's multi_error: 0.564972
# [367]	valid_0's multi_error: 0.564966
# [368]	valid_0's multi_error: 0.564914
# [369]	valid_0's multi_error: 0.564957
# [370]	valid_0's multi_error: 0.564901
# [371]	valid_0's multi_error: 0.564889
# [372]	valid_0's multi_error: 0.564917
# [373]	valid_0's multi_error: 0.564859
# [374]	valid_0's multi_error: 0.564825
# [375]	valid_0's multi_error: 0.564868
# [376]	valid_0's multi_error: 0.56481
# [377]	valid_0's multi_error: 0.564784
# [378]	valid_0's multi_error: 0.564738
# [379]	valid_0's multi_error: 0.564772
# [380]	valid_0's multi_error: 0.564708
# [381]	valid_0's multi_error: 0.564653
# [382]	valid_0's multi_error: 0.564672
# [383]	valid_0's multi_error: 0.564596
# [384]	valid_0's multi_error: 0.564542
# [385]	valid_0's multi_error: 0.564562
# [386]	valid_0's multi_error: 0.564511
# [387]	valid_0's multi_error: 0.564451
# [388]	valid_0's multi_error: 0.564439
# [389]	valid_0's multi_error: 0.564383
# [390]	valid_0's multi_error: 0.56436
# [391]	valid_0's multi_error: 0.564301
# [392]	valid_0's multi_error: 0.56429
# [393]	valid_0's multi_error: 0.564268
# [394]	valid_0's multi_error: 0.564272
# [395]	valid_0's multi_error: 0.564272
# [396]	valid_0's multi_error: 0.564189
# [397]	valid_0's multi_error: 0.564232
# [398]	valid_0's multi_error: 0.564214
# [399]	valid_0's multi_error: 0.564163
# [400]	valid_0's multi_error: 0.564108
# [401]	valid_0's multi_error: 0.56409
# [402]	valid_0's multi_error: 0.564048
# [403]	valid_0's multi_error: 0.564051
# [404]	valid_0's multi_error: 0.564075
# [405]	valid_0's multi_error: 0.564087
# [406]	valid_0's multi_error: 0.564066
# [407]	valid_0's multi_error: 0.564084
# [408]	valid_0's multi_error: 0.564031
# [409]	valid_0's multi_error: 0.563951
# [410]	valid_0's multi_error: 0.564005
# [411]	valid_0's multi_error: 0.56396
# [412]	valid_0's multi_error: 0.563993
# [413]	valid_0's multi_error: 0.563884
# [414]	valid_0's multi_error: 0.563842
# [415]	valid_0's multi_error: 0.563795
# [416]	valid_0's multi_error: 0.563762
# [417]	valid_0's multi_error: 0.563663
# [418]	valid_0's multi_error: 0.563653
# [419]	valid_0's multi_error: 0.563631
# [420]	valid_0's multi_error: 0.563589
# [421]	valid_0's multi_error: 0.563601
# [422]	valid_0's multi_error: 0.563602
# [423]	valid_0's multi_error: 0.563553
# [424]	valid_0's multi_error: 0.563513
# [425]	valid_0's multi_error: 0.563519
# [426]	valid_0's multi_error: 0.563475
# [427]	valid_0's multi_error: 0.563474
# [428]	valid_0's multi_error: 0.563469
# [429]	valid_0's multi_error: 0.563495
# [430]	valid_0's multi_error: 0.563513
# [431]	valid_0's multi_error: 0.563539
# [432]	valid_0's multi_error: 0.56351
# [433]	valid_0's multi_error: 0.563453
# [434]	valid_0's multi_error: 0.563478
# [435]	valid_0's multi_error: 0.563508
# [436]	valid_0's multi_error: 0.563459
# [437]	valid_0's multi_error: 0.563399
# [438]	valid_0's multi_error: 0.563326
# [439]	valid_0's multi_error: 0.563283
# [440]	valid_0's multi_error: 0.563342
# [441]	valid_0's multi_error: 0.563293
# [442]	valid_0's multi_error: 0.563266
# [443]	valid_0's multi_error: 0.563239
# [444]	valid_0's multi_error: 0.563295
# [445]	valid_0's multi_error: 0.563226
# [446]	valid_0's multi_error: 0.563219
# [447]	valid_0's multi_error: 0.563181
# [448]	valid_0's multi_error: 0.563192
# [449]	valid_0's multi_error: 0.563228
# [450]	valid_0's multi_error: 0.563211
# [451]	valid_0's multi_error: 0.563144
# [452]	valid_0's multi_error: 0.563147
# [453]	valid_0's multi_error: 0.563077
# [454]	valid_0's multi_error: 0.563099
# [455]	valid_0's multi_error: 0.563062
# [456]	valid_0's multi_error: 0.563072
# [457]	valid_0's multi_error: 0.563068
# [458]	valid_0's multi_error: 0.56305
# [459]	valid_0's multi_error: 0.563056
# [460]	valid_0's multi_error: 0.563057
# [461]	valid_0's multi_error: 0.563008
# [462]	valid_0's multi_error: 0.563039
# [463]	valid_0's multi_error: 0.563013
# [464]	valid_0's multi_error: 0.562974
# [465]	valid_0's multi_error: 0.562963
# [466]	valid_0's multi_error: 0.562935
# [467]	valid_0's multi_error: 0.562968
# [468]	valid_0's multi_error: 0.562922
# [469]	valid_0's multi_error: 0.562862
# [470]	valid_0's multi_error: 0.562871
# [471]	valid_0's multi_error: 0.562863
# [472]	valid_0's multi_error: 0.562831
# [473]	valid_0's multi_error: 0.562819
# [474]	valid_0's multi_error: 0.562798
# [475]	valid_0's multi_error: 0.562789
# [476]	valid_0's multi_error: 0.562798
# [477]	valid_0's multi_error: 0.562874
# [478]	valid_0's multi_error: 0.562884
# [479]	valid_0's multi_error: 0.562856
# [480]	valid_0's multi_error: 0.562784
# [481]	valid_0's multi_error: 0.562666
# [482]	valid_0's multi_error: 0.562701
# [483]	valid_0's multi_error: 0.562668
# [484]	valid_0's multi_error: 0.562654
# [485]	valid_0's multi_error: 0.562662
# [486]	valid_0's multi_error: 0.562659
# [487]	valid_0's multi_error: 0.562622
# [488]	valid_0's multi_error: 0.562662
# [489]	valid_0's multi_error: 0.562626
# [490]	valid_0's multi_error: 0.562563
# [491]	valid_0's multi_error: 0.562563
# [492]	valid_0's multi_error: 0.56251
# [493]	valid_0's multi_error: 0.562475
# [494]	valid_0's multi_error: 0.562462
# [495]	valid_0's multi_error: 0.562468
# [496]	valid_0's multi_error: 0.56246
# [497]	valid_0's multi_error: 0.562436
# [498]	valid_0's multi_error: 0.562425
# [499]	valid_0's multi_error: 0.562432
# [500]	valid_0's multi_error: 0.562405
# [501]	valid_0's multi_error: 0.562422
# [502]	valid_0's multi_error: 0.562396
# [503]	valid_0's multi_error: 0.562398
# [504]	valid_0's multi_error: 0.562396
# [505]	valid_0's multi_error: 0.562398
# [506]	valid_0's multi_error: 0.562316
# [507]	valid_0's multi_error: 0.562313
# [508]	valid_0's multi_error: 0.562269
# [509]	valid_0's multi_error: 0.562266
# [510]	valid_0's multi_error: 0.562251
# [511]	valid_0's multi_error: 0.562257
# [512]	valid_0's multi_error: 0.562238
# [513]	valid_0's multi_error: 0.562213
# [514]	valid_0's multi_error: 0.562241
# [515]	valid_0's multi_error: 0.562177
# [516]	valid_0's multi_error: 0.562262
# [517]	valid_0's multi_error: 0.562265
# [518]	valid_0's multi_error: 0.562241
# [519]	valid_0's multi_error: 0.562242
# [520]	valid_0's multi_error: 0.562183
# [521]	valid_0's multi_error: 0.562242
# [522]	valid_0's multi_error: 0.562232
# [523]	valid_0's multi_error: 0.562233
# [524]	valid_0's multi_error: 0.562232
# [525]	valid_0's multi_error: 0.562198
# [526]	valid_0's multi_error: 0.562217
# [527]	valid_0's multi_error: 0.562163
# [528]	valid_0's multi_error: 0.562148
# [529]	valid_0's multi_error: 0.562113
# [530]	valid_0's multi_error: 0.562119
# [531]	valid_0's multi_error: 0.562101
# [532]	valid_0's multi_error: 0.562102
# [533]	valid_0's multi_error: 0.562123
# [534]	valid_0's multi_error: 0.562116
# [535]	valid_0's multi_error: 0.562117
# [536]	valid_0's multi_error: 0.562075
# [537]	valid_0's multi_error: 0.562078
# [538]	valid_0's multi_error: 0.562071
# [539]	valid_0's multi_error: 0.562044
# [540]	valid_0's multi_error: 0.562004
# [541]	valid_0's multi_error: 0.561987
# [542]	valid_0's multi_error: 0.56199
# [543]	valid_0's multi_error: 0.561974
# [544]	valid_0's multi_error: 0.561913
# [545]	valid_0's multi_error: 0.561892
# [546]	valid_0's multi_error: 0.561871
# [547]	valid_0's multi_error: 0.561842
# [548]	valid_0's multi_error: 0.561842
# [549]	valid_0's multi_error: 0.561828
# [550]	valid_0's multi_error: 0.561836
# [551]	valid_0's multi_error: 0.561813
# [552]	valid_0's multi_error: 0.56179
# [553]	valid_0's multi_error: 0.561804
# [554]	valid_0's multi_error: 0.561804
# [555]	valid_0's multi_error: 0.561769
# [556]	valid_0's multi_error: 0.561769
# [557]	valid_0's multi_error: 0.561787
# [558]	valid_0's multi_error: 0.561772
# [559]	valid_0's multi_error: 0.561745
# [560]	valid_0's multi_error: 0.561753
# [561]	valid_0's multi_error: 0.561811
# [562]	valid_0's multi_error: 0.56181
# [563]	valid_0's multi_error: 0.561781
# [564]	valid_0's multi_error: 0.561792
# [565]	valid_0's multi_error: 0.561839
# [566]	valid_0's multi_error: 0.561839
# [567]	valid_0's multi_error: 0.561841
# [568]	valid_0's multi_error: 0.56176
# [569]	valid_0's multi_error: 0.561792
# [570]	valid_0's multi_error: 0.561796
# [571]	valid_0's multi_error: 0.561832
# [572]	valid_0's multi_error: 0.561775
# [573]	valid_0's multi_error: 0.561738
# [574]	valid_0's multi_error: 0.561742
# [575]	valid_0's multi_error: 0.561714
# [576]	valid_0's multi_error: 0.561689
# [577]	valid_0's multi_error: 0.561711
# [578]	valid_0's multi_error: 0.561707
# [579]	valid_0's multi_error: 0.561656
# [580]	valid_0's multi_error: 0.561641
# [581]	valid_0's multi_error: 0.561616
# [582]	valid_0's multi_error: 0.561592
# [583]	valid_0's multi_error: 0.561622
# [584]	valid_0's multi_error: 0.561626
# [585]	valid_0's multi_error: 0.561586
# [586]	valid_0's multi_error: 0.561599
# [587]	valid_0's multi_error: 0.561566
# [588]	valid_0's multi_error: 0.561528
# [589]	valid_0's multi_error: 0.561545
# [590]	valid_0's multi_error: 0.561486
# [591]	valid_0's multi_error: 0.56149
# [592]	valid_0's multi_error: 0.561428
# [593]	valid_0's multi_error: 0.561416
# [594]	valid_0's multi_error: 0.561402
# [595]	valid_0's multi_error: 0.561413
# [596]	valid_0's multi_error: 0.561432
# [597]	valid_0's multi_error: 0.561478
# [598]	valid_0's multi_error: 0.561462
# [599]	valid_0's multi_error: 0.561447
# [600]	valid_0's multi_error: 0.561453
# [601]	valid_0's multi_error: 0.561459
# [602]	valid_0's multi_error: 0.561395
# [603]	valid_0's multi_error: 0.561395
# [604]	valid_0's multi_error: 0.561335
# [605]	valid_0's multi_error: 0.561359
# [606]	valid_0's multi_error: 0.561378
# [607]	valid_0's multi_error: 0.561366
# [608]	valid_0's multi_error: 0.561329
# [609]	valid_0's multi_error: 0.561384
# [610]	valid_0's multi_error: 0.56139
# [611]	valid_0's multi_error: 0.561308
# [612]	valid_0's multi_error: 0.561307
# [613]	valid_0's multi_error: 0.56132
# [614]	valid_0's multi_error: 0.561284
# [615]	valid_0's multi_error: 0.561277
# [616]	valid_0's multi_error: 0.561235
# [617]	valid_0's multi_error: 0.561229
# [618]	valid_0's multi_error: 0.56121
# [619]	valid_0's multi_error: 0.561223
# [620]	valid_0's multi_error: 0.561196
# [621]	valid_0's multi_error: 0.561172
# [622]	valid_0's multi_error: 0.561169
# [623]	valid_0's multi_error: 0.56121
# [624]	valid_0's multi_error: 0.561192
# [625]	valid_0's multi_error: 0.561172
# [626]	valid_0's multi_error: 0.56119
# [627]	valid_0's multi_error: 0.561154
# [628]	valid_0's multi_error: 0.561171
# [629]	valid_0's multi_error: 0.561162
# [630]	valid_0's multi_error: 0.561138
# [631]	valid_0's multi_error: 0.561144
# [632]	valid_0's multi_error: 0.561141
# [633]	valid_0's multi_error: 0.561089
# [634]	valid_0's multi_error: 0.561065
# [635]	valid_0's multi_error: 0.561069
# [636]	valid_0's multi_error: 0.561053
# [637]	valid_0's multi_error: 0.561059
# [638]	valid_0's multi_error: 0.561083
# [639]	valid_0's multi_error: 0.561059
# [640]	valid_0's multi_error: 0.56106
# [641]	valid_0's multi_error: 0.560977
# [642]	valid_0's multi_error: 0.56098
# [643]	valid_0's multi_error: 0.560957
# [644]	valid_0's multi_error: 0.560966
# [645]	valid_0's multi_error: 0.560963
# [646]	valid_0's multi_error: 0.560948
# [647]	valid_0's multi_error: 0.560923
# [648]	valid_0's multi_error: 0.560935
# [649]	valid_0's multi_error: 0.560931
# [650]	valid_0's multi_error: 0.560922
# [651]	valid_0's multi_error: 0.560893
# [652]	valid_0's multi_error: 0.560877
# [653]	valid_0's multi_error: 0.560845
# [654]	valid_0's multi_error: 0.560808
# [655]	valid_0's multi_error: 0.560828
# [656]	valid_0's multi_error: 0.56085
# [657]	valid_0's multi_error: 0.560831
# [658]	valid_0's multi_error: 0.56081
# [659]	valid_0's multi_error: 0.560807
# [660]	valid_0's multi_error: 0.560783
# [661]	valid_0's multi_error: 0.560796
# [662]	valid_0's multi_error: 0.560811
# [663]	valid_0's multi_error: 0.560819
# [664]	valid_0's multi_error: 0.560828
# [665]	valid_0's multi_error: 0.560781
# [666]	valid_0's multi_error: 0.560784
# [667]	valid_0's multi_error: 0.560787
# [668]	valid_0's multi_error: 0.560814
# [669]	valid_0's multi_error: 0.560831
# [670]	valid_0's multi_error: 0.560856
# [671]	valid_0's multi_error: 0.560831
# [672]	valid_0's multi_error: 0.560831
# [673]	valid_0's multi_error: 0.560771
# [674]	valid_0's multi_error: 0.560753
# [675]	valid_0's multi_error: 0.560732
# [676]	valid_0's multi_error: 0.560732
# [677]	valid_0's multi_error: 0.560674
# [678]	valid_0's multi_error: 0.560654
# [679]	valid_0's multi_error: 0.560671
# [680]	valid_0's multi_error: 0.560732
# [681]	valid_0's multi_error: 0.560751
# [682]	valid_0's multi_error: 0.560705
# [683]	valid_0's multi_error: 0.560672
# [684]	valid_0's multi_error: 0.560695
# [685]	valid_0's multi_error: 0.560663
# [686]	valid_0's multi_error: 0.560669
# [687]	valid_0's multi_error: 0.560695
# [688]	valid_0's multi_error: 0.560677
# [689]	valid_0's multi_error: 0.560671
# [690]	valid_0's multi_error: 0.560666
# [691]	valid_0's multi_error: 0.560647
# [692]	valid_0's multi_error: 0.560617
# [693]	valid_0's multi_error: 0.560602
# [694]	valid_0's multi_error: 0.560595
# [695]	valid_0's multi_error: 0.560601
# [696]	valid_0's multi_error: 0.560633
# [697]	valid_0's multi_error: 0.560607
# [698]	valid_0's multi_error: 0.560601
# [699]	valid_0's multi_error: 0.560587
# [700]	valid_0's multi_error: 0.560593
# [701]	valid_0's multi_error: 0.560596
# [702]	valid_0's multi_error: 0.560572
# [703]	valid_0's multi_error: 0.560569
# [704]	valid_0's multi_error: 0.560604
# [705]	valid_0's multi_error: 0.560599
# [706]	valid_0's multi_error: 0.56059
# [707]	valid_0's multi_error: 0.560602
# [708]	valid_0's multi_error: 0.560602
# [709]	valid_0's multi_error: 0.560578
# [710]	valid_0's multi_error: 0.560586
# [711]	valid_0's multi_error: 0.560602
# [712]	valid_0's multi_error: 0.560589
# [713]	valid_0's multi_error: 0.560553
# [714]	valid_0's multi_error: 0.560595
# [715]	valid_0's multi_error: 0.560531
# [716]	valid_0's multi_error: 0.560566
# [717]	valid_0's multi_error: 0.56055
# [718]	valid_0's multi_error: 0.560539
# [719]	valid_0's multi_error: 0.560535
# [720]	valid_0's multi_error: 0.560544
# [721]	valid_0's multi_error: 0.560559
# [722]	valid_0's multi_error: 0.560568
# [723]	valid_0's multi_error: 0.560557
# [724]	valid_0's multi_error: 0.560566
# [725]	valid_0's multi_error: 0.560578
# [726]	valid_0's multi_error: 0.56056
# [727]	valid_0's multi_error: 0.560569
# [728]	valid_0's multi_error: 0.56058
# [729]	valid_0's multi_error: 0.560608
# [730]	valid_0's multi_error: 0.560542
# [731]	valid_0's multi_error: 0.560529
# [732]	valid_0's multi_error: 0.560501
# [733]	valid_0's multi_error: 0.560492
# [734]	valid_0's multi_error: 0.560526
# [735]	valid_0's multi_error: 0.560459
# [736]	valid_0's multi_error: 0.560451
# [737]	valid_0's multi_error: 0.560425
# [738]	valid_0's multi_error: 0.560422
# [739]	valid_0's multi_error: 0.560429
# [740]	valid_0's multi_error: 0.560438
# [741]	valid_0's multi_error: 0.560419
# [742]	valid_0's multi_error: 0.56042
# [743]	valid_0's multi_error: 0.560401
# [744]	valid_0's multi_error: 0.560378
# [745]	valid_0's multi_error: 0.560381
# [746]	valid_0's multi_error: 0.560402
# [747]	valid_0's multi_error: 0.560411
# [748]	valid_0's multi_error: 0.560422
# [749]	valid_0's multi_error: 0.560365
# [750]	valid_0's multi_error: 0.56035
# [751]	valid_0's multi_error: 0.560331
# [752]	valid_0's multi_error: 0.560351
# [753]	valid_0's multi_error: 0.560342
# [754]	valid_0's multi_error: 0.560342
# [755]	valid_0's multi_error: 0.560342
# [756]	valid_0's multi_error: 0.560292
# [757]	valid_0's multi_error: 0.560275
# [758]	valid_0's multi_error: 0.560275
# [759]	valid_0's multi_error: 0.560301
# [760]	valid_0's multi_error: 0.560316
# [761]	valid_0's multi_error: 0.560296
# [762]	valid_0's multi_error: 0.560322
# [763]	valid_0's multi_error: 0.560342
# [764]	valid_0's multi_error: 0.560332
# [765]	valid_0's multi_error: 0.560319
# [766]	valid_0's multi_error: 0.560302
# [767]	valid_0's multi_error: 0.560269
# [768]	valid_0's multi_error: 0.560262
# [769]	valid_0's multi_error: 0.560259
# [770]	valid_0's multi_error: 0.560286
# [771]	valid_0's multi_error: 0.560308
# [772]	valid_0's multi_error: 0.560296
# [773]	valid_0's multi_error: 0.560262
# [774]	valid_0's multi_error: 0.560253
# [775]	valid_0's multi_error: 0.560269
# [776]	valid_0's multi_error: 0.560247
# [777]	valid_0's multi_error: 0.560245
# [778]	valid_0's multi_error: 0.560222
# [779]	valid_0's multi_error: 0.560235
# [780]	valid_0's multi_error: 0.560235
# [781]	valid_0's multi_error: 0.560229
# [782]	valid_0's multi_error: 0.560214
# [783]	valid_0's multi_error: 0.56018
# [784]	valid_0's multi_error: 0.560211
# [785]	valid_0's multi_error: 0.56019
# [786]	valid_0's multi_error: 0.560205
# [787]	valid_0's multi_error: 0.56018
# [788]	valid_0's multi_error: 0.560177
# [789]	valid_0's multi_error: 0.560171
# [790]	valid_0's multi_error: 0.560166
# [791]	valid_0's multi_error: 0.560128
# [792]	valid_0's multi_error: 0.560119
# [793]	valid_0's multi_error: 0.560122
# [794]	valid_0's multi_error: 0.560102
# [795]	valid_0's multi_error: 0.560036
# [796]	valid_0's multi_error: 0.560065
# [797]	valid_0's multi_error: 0.560038
# [798]	valid_0's multi_error: 0.560036
# [799]	valid_0's multi_error: 0.560078
# [800]	valid_0's multi_error: 0.560086
# [801]	valid_0's multi_error: 0.560045
# [802]	valid_0's multi_error: 0.559987
# [803]	valid_0's multi_error: 0.559957
# [804]	valid_0's multi_error: 0.55998
# [805]	valid_0's multi_error: 0.559971
# [806]	valid_0's multi_error: 0.559956
# [807]	valid_0's multi_error: 0.559945
# [808]	valid_0's multi_error: 0.559938
# [809]	valid_0's multi_error: 0.559951
# [810]	valid_0's multi_error: 0.559931
# [811]	valid_0's multi_error: 0.559916
# [812]	valid_0's multi_error: 0.559899
# [813]	valid_0's multi_error: 0.559883
# [814]	valid_0's multi_error: 0.559877
# [815]	valid_0's multi_error: 0.559893
# [816]	valid_0's multi_error: 0.559939
# [817]	valid_0's multi_error: 0.559971
# [818]	valid_0's multi_error: 0.560001
# [819]	valid_0's multi_error: 0.559981
# [820]	valid_0's multi_error: 0.559984
# [821]	valid_0's multi_error: 0.559947
# [822]	valid_0's multi_error: 0.55995
# [823]	valid_0's multi_error: 0.559911
# [824]	valid_0's multi_error: 0.559899
# [825]	valid_0's multi_error: 0.559895
# [826]	valid_0's multi_error: 0.559928
# [827]	valid_0's multi_error: 0.559889
# [828]	valid_0's multi_error: 0.559893
# [829]	valid_0's multi_error: 0.559917
# [830]	valid_0's multi_error: 0.55991
# [831]	valid_0's multi_error: 0.559935
# [832]	valid_0's multi_error: 0.559922
# [833]	valid_0's multi_error: 0.559947
# [834]	valid_0's multi_error: 0.559911
# [835]	valid_0's multi_error: 0.559865
# [836]	valid_0's multi_error: 0.559862
# [837]	valid_0's multi_error: 0.559872
# [838]	valid_0's multi_error: 0.55986
# [839]	valid_0's multi_error: 0.559842
# [840]	valid_0's multi_error: 0.559833
# [841]	valid_0's multi_error: 0.559841
# [842]	valid_0's multi_error: 0.559859
# [843]	valid_0's multi_error: 0.559866
# [844]	valid_0's multi_error: 0.559884
# [845]	valid_0's multi_error: 0.55981
# [846]	valid_0's multi_error: 0.55981
# [847]	valid_0's multi_error: 0.55979
# [848]	valid_0's multi_error: 0.559732
# [849]	valid_0's multi_error: 0.559735
# [850]	valid_0's multi_error: 0.55975
# [851]	valid_0's multi_error: 0.559725
# [852]	valid_0's multi_error: 0.559728
# [853]	valid_0's multi_error: 0.559693
# [854]	valid_0's multi_error: 0.559704
# [855]	valid_0's multi_error: 0.559701
# [856]	valid_0's multi_error: 0.559687
# [857]	valid_0's multi_error: 0.55968
# [858]	valid_0's multi_error: 0.559686
# [859]	valid_0's multi_error: 0.559705
# [860]	valid_0's multi_error: 0.559656
# [861]	valid_0's multi_error: 0.559644
# [862]	valid_0's multi_error: 0.559623
# [863]	valid_0's multi_error: 0.559622
# [864]	valid_0's multi_error: 0.559622
# [865]	valid_0's multi_error: 0.559595
# [866]	valid_0's multi_error: 0.559619
# [867]	valid_0's multi_error: 0.559625
# [868]	valid_0's multi_error: 0.55962
# [869]	valid_0's multi_error: 0.559614
# [870]	valid_0's multi_error: 0.559653
# [871]	valid_0's multi_error: 0.559651
# [872]	valid_0's multi_error: 0.559638
# [873]	valid_0's multi_error: 0.559639
# [874]	valid_0's multi_error: 0.559599
# [875]	valid_0's multi_error: 0.559602
# [876]	valid_0's multi_error: 0.559581
# [877]	valid_0's multi_error: 0.55958
# [878]	valid_0's multi_error: 0.559584
# [879]	valid_0's multi_error: 0.559565
# [880]	valid_0's multi_error: 0.559595
# [881]	valid_0's multi_error: 0.559628
# [882]	valid_0's multi_error: 0.559633
# [883]	valid_0's multi_error: 0.559614
# [884]	valid_0's multi_error: 0.55962
# [885]	valid_0's multi_error: 0.559639
# [886]	valid_0's multi_error: 0.559595
# [887]	valid_0's multi_error: 0.559622
# [888]	valid_0's multi_error: 0.559626
# [889]	valid_0's multi_error: 0.559633
# [890]	valid_0's multi_error: 0.559628
# [891]	valid_0's multi_error: 0.559586
# [892]	valid_0's multi_error: 0.559548
# [893]	valid_0's multi_error: 0.559544
# [894]	valid_0's multi_error: 0.559542
# [895]	valid_0's multi_error: 0.55955
# [896]	valid_0's multi_error: 0.559539
# [897]	valid_0's multi_error: 0.559533
# [898]	valid_0's multi_error: 0.55951
# [899]	valid_0's multi_error: 0.559547
# [900]	valid_0's multi_error: 0.559531
# [901]	valid_0's multi_error: 0.559535
# [902]	valid_0's multi_error: 0.559516
# [903]	valid_0's multi_error: 0.559532
# [904]	valid_0's multi_error: 0.559525
# [905]	valid_0's multi_error: 0.559504
# [906]	valid_0's multi_error: 0.559526
# [907]	valid_0's multi_error: 0.559529
# [908]	valid_0's multi_error: 0.559459
# [909]	valid_0's multi_error: 0.559435
# [910]	valid_0's multi_error: 0.559423
# [911]	valid_0's multi_error: 0.559416
# [912]	valid_0's multi_error: 0.559396
# [913]	valid_0's multi_error: 0.559414
# [914]	valid_0's multi_error: 0.559447
# [915]	valid_0's multi_error: 0.559396
# [916]	valid_0's multi_error: 0.559384
# [917]	valid_0's multi_error: 0.559329
# [918]	valid_0's multi_error: 0.559332
# [919]	valid_0's multi_error: 0.559371
# [920]	valid_0's multi_error: 0.559323
# [921]	valid_0's multi_error: 0.559335
# [922]	valid_0's multi_error: 0.559333
# [923]	valid_0's multi_error: 0.559338
# [924]	valid_0's multi_error: 0.559323
# [925]	valid_0's multi_error: 0.559336
# [926]	valid_0's multi_error: 0.559339
# [927]	valid_0's multi_error: 0.559336
# [928]	valid_0's multi_error: 0.559301
# [929]	valid_0's multi_error: 0.559341
# [930]	valid_0's multi_error: 0.559368
# [931]	valid_0's multi_error: 0.559372
# [932]	valid_0's multi_error: 0.559357
# [933]	valid_0's multi_error: 0.559339
# [934]	valid_0's multi_error: 0.559319
# [935]	valid_0's multi_error: 0.559304
# [936]	valid_0's multi_error: 0.559283
# [937]	valid_0's multi_error: 0.55928
# [938]	valid_0's multi_error: 0.55929
# [939]	valid_0's multi_error: 0.559263
# [940]	valid_0's multi_error: 0.55925
# [941]	valid_0's multi_error: 0.559304
# [942]	valid_0's multi_error: 0.559292
# [943]	valid_0's multi_error: 0.559265
# [944]	valid_0's multi_error: 0.559286
# [945]	valid_0's multi_error: 0.559284
# [946]	valid_0's multi_error: 0.559263
# [947]	valid_0's multi_error: 0.55926
# [948]	valid_0's multi_error: 0.55925
# [949]	valid_0's multi_error: 0.559216
# [950]	valid_0's multi_error: 0.559232
# [951]	valid_0's multi_error: 0.559242
# [952]	valid_0's multi_error: 0.559257
# [953]	valid_0's multi_error: 0.559175
# [954]	valid_0's multi_error: 0.559196
# [955]	valid_0's multi_error: 0.559217
# [956]	valid_0's multi_error: 0.559202
# [957]	valid_0's multi_error: 0.559187
# [958]	valid_0's multi_error: 0.559208
# [959]	valid_0's multi_error: 0.559211
# [960]	valid_0's multi_error: 0.559217
# [961]	valid_0's multi_error: 0.559248
# [962]	valid_0's multi_error: 0.559211
# [963]	valid_0's multi_error: 0.559245
# [964]	valid_0's multi_error: 0.559239
# [965]	valid_0's multi_error: 0.559245
# [966]	valid_0's multi_error: 0.559228
# [967]	valid_0's multi_error: 0.559226
# [968]	valid_0's multi_error: 0.559278
# [969]	valid_0's multi_error: 0.55922
# [970]	valid_0's multi_error: 0.559269
# [971]	valid_0's multi_error: 0.559274
# [972]	valid_0's multi_error: 0.559245
# [973]	valid_0's multi_error: 0.559236
# [974]	valid_0's multi_error: 0.559214
# [975]	valid_0's multi_error: 0.55922
# [976]	valid_0's multi_error: 0.559223
# [977]	valid_0's multi_error: 0.559229
# [978]	valid_0's multi_error: 0.559225
# [979]	valid_0's multi_error: 0.559222
# [980]	valid_0's multi_error: 0.559181
# [981]	valid_0's multi_error: 0.559216
# [982]	valid_0's multi_error: 0.559199
# [983]	valid_0's multi_error: 0.559192
# [984]	valid_0's multi_error: 0.559171
# [985]	valid_0's multi_error: 0.559189
# [986]	valid_0's multi_error: 0.559162
# [987]	valid_0's multi_error: 0.559154
# [988]	valid_0's multi_error: 0.559141
# [989]	valid_0's multi_error: 0.559122
# [990]	valid_0's multi_error: 0.559142
# [991]	valid_0's multi_error: 0.559162
# [992]	valid_0's multi_error: 0.559147
# [993]	valid_0's multi_error: 0.559175
# [994]	valid_0's multi_error: 0.559165
# [995]	valid_0's multi_error: 0.559172
# [996]	valid_0's multi_error: 0.559174
# [997]	valid_0's multi_error: 0.559136
# [998]	valid_0's multi_error: 0.559168
# [999]	valid_0's multi_error: 0.559138
# [1000]	valid_0's multi_error: 0.559151
# Did not meet early stopping. Best iteration is:
# [989]	valid_0's multi_error: 0.559122
# 1
# training start...
# [1]	valid_0's multi_error: 0.701493
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's multi_error: 0.701493
# [3]	valid_0's multi_error: 0.701493
# [4]	valid_0's multi_error: 0.696881
# [5]	valid_0's multi_error: 0.690103
# [6]	valid_0's multi_error: 0.682325
# [7]	valid_0's multi_error: 0.674881
# [8]	valid_0's multi_error: 0.669131
# [9]	valid_0's multi_error: 0.663018
# [10]	valid_0's multi_error: 0.656627
# [11]	valid_0's multi_error: 0.65061
# [12]	valid_0's multi_error: 0.645167
# [13]	valid_0's multi_error: 0.640091
# [14]	valid_0's multi_error: 0.636206
# [15]	valid_0's multi_error: 0.63356
# [16]	valid_0's multi_error: 0.631161
# [17]	valid_0's multi_error: 0.628187
# [18]	valid_0's multi_error: 0.626012
# [19]	valid_0's multi_error: 0.623381
# [20]	valid_0's multi_error: 0.621927
# [21]	valid_0's multi_error: 0.620578
# [22]	valid_0's multi_error: 0.619101
# [23]	valid_0's multi_error: 0.617825
# [24]	valid_0's multi_error: 0.616755
# [25]	valid_0's multi_error: 0.615621
# [26]	valid_0's multi_error: 0.614652
# [27]	valid_0's multi_error: 0.613437
# [28]	valid_0's multi_error: 0.612525
# [29]	valid_0's multi_error: 0.611863
# [30]	valid_0's multi_error: 0.610855
# [31]	valid_0's multi_error: 0.60971
# [32]	valid_0's multi_error: 0.609076
# [33]	valid_0's multi_error: 0.608297
# [34]	valid_0's multi_error: 0.607363
# [35]	valid_0's multi_error: 0.606679
# [36]	valid_0's multi_error: 0.606072
# [37]	valid_0's multi_error: 0.605385
# [38]	valid_0's multi_error: 0.604652
# [39]	valid_0's multi_error: 0.604019
# [40]	valid_0's multi_error: 0.60337
# [41]	valid_0's multi_error: 0.602833
# [42]	valid_0's multi_error: 0.602134
# [43]	valid_0's multi_error: 0.601639
# [44]	valid_0's multi_error: 0.601273
# [45]	valid_0's multi_error: 0.600799
# [46]	valid_0's multi_error: 0.600393
# [47]	valid_0's multi_error: 0.599961
# [48]	valid_0's multi_error: 0.599321
# [49]	valid_0's multi_error: 0.598913
# [50]	valid_0's multi_error: 0.598518
# [51]	valid_0's multi_error: 0.597858
# [52]	valid_0's multi_error: 0.597406
# [53]	valid_0's multi_error: 0.59717
# [54]	valid_0's multi_error: 0.596734
# [55]	valid_0's multi_error: 0.596346
# [56]	valid_0's multi_error: 0.59596
# [57]	valid_0's multi_error: 0.595572
# [58]	valid_0's multi_error: 0.59524
# [59]	valid_0's multi_error: 0.594878
# [60]	valid_0's multi_error: 0.594301
# [61]	valid_0's multi_error: 0.593954
# [62]	valid_0's multi_error: 0.593622
# [63]	valid_0's multi_error: 0.593319
# [64]	valid_0's multi_error: 0.592937
# [65]	valid_0's multi_error: 0.592587
# [66]	valid_0's multi_error: 0.592357
# [67]	valid_0's multi_error: 0.591988
# [68]	valid_0's multi_error: 0.591693
# [69]	valid_0's multi_error: 0.5913
# [70]	valid_0's multi_error: 0.591031
# [71]	valid_0's multi_error: 0.590779
# [72]	valid_0's multi_error: 0.590397
# [73]	valid_0's multi_error: 0.590203
# [74]	valid_0's multi_error: 0.589967
# [75]	valid_0's multi_error: 0.589675
# [76]	valid_0's multi_error: 0.589367
# [77]	valid_0's multi_error: 0.589034
# [78]	valid_0's multi_error: 0.588733
# [79]	valid_0's multi_error: 0.588387
# [80]	valid_0's multi_error: 0.588088
# [81]	valid_0's multi_error: 0.587937
# [82]	valid_0's multi_error: 0.587615
# [83]	valid_0's multi_error: 0.587325
# [84]	valid_0's multi_error: 0.587143
# [85]	valid_0's multi_error: 0.586882
# [86]	valid_0's multi_error: 0.586666
# [87]	valid_0's multi_error: 0.586485
# [88]	valid_0's multi_error: 0.586296
# [89]	valid_0's multi_error: 0.586148
# [90]	valid_0's multi_error: 0.585896
# [91]	valid_0's multi_error: 0.585606
# [92]	valid_0's multi_error: 0.585331
# [93]	valid_0's multi_error: 0.585207
# [94]	valid_0's multi_error: 0.584881
# [95]	valid_0's multi_error: 0.584497
# [96]	valid_0's multi_error: 0.584519
# [97]	valid_0's multi_error: 0.584193
# [98]	valid_0's multi_error: 0.583957
# [99]	valid_0's multi_error: 0.583903
# [100]	valid_0's multi_error: 0.583603
# [101]	valid_0's multi_error: 0.583501
# [102]	valid_0's multi_error: 0.583236
# [103]	valid_0's multi_error: 0.583028
# [104]	valid_0's multi_error: 0.58279
# [105]	valid_0's multi_error: 0.582443
# [106]	valid_0's multi_error: 0.582409
# [107]	valid_0's multi_error: 0.582239
# [108]	valid_0's multi_error: 0.582101
# [109]	valid_0's multi_error: 0.582009
# [110]	valid_0's multi_error: 0.581757
# [111]	valid_0's multi_error: 0.581675
# [112]	valid_0's multi_error: 0.581575
# [113]	valid_0's multi_error: 0.581403
# [114]	valid_0's multi_error: 0.581293
# [115]	valid_0's multi_error: 0.581
# [116]	valid_0's multi_error: 0.580879
# [117]	valid_0's multi_error: 0.580681
# [118]	valid_0's multi_error: 0.58051
# [119]	valid_0's multi_error: 0.580272
# [120]	valid_0's multi_error: 0.580173
# [121]	valid_0's multi_error: 0.58013
# [122]	valid_0's multi_error: 0.579939
# [123]	valid_0's multi_error: 0.579773
# [124]	valid_0's multi_error: 0.57969
# [125]	valid_0's multi_error: 0.579578
# [126]	valid_0's multi_error: 0.579469
# [127]	valid_0's multi_error: 0.579218
# [128]	valid_0's multi_error: 0.579154
# [129]	valid_0's multi_error: 0.578855
# [130]	valid_0's multi_error: 0.578751
# [131]	valid_0's multi_error: 0.57867
# [132]	valid_0's multi_error: 0.578376
# [133]	valid_0's multi_error: 0.578339
# [134]	valid_0's multi_error: 0.578293
# [135]	valid_0's multi_error: 0.578103
# [136]	valid_0's multi_error: 0.57803
# [137]	valid_0's multi_error: 0.577885
# [138]	valid_0's multi_error: 0.577848
# [139]	valid_0's multi_error: 0.577722
# [140]	valid_0's multi_error: 0.577655
# [141]	valid_0's multi_error: 0.577516
# [142]	valid_0's multi_error: 0.577291
# [143]	valid_0's multi_error: 0.577185
# [144]	valid_0's multi_error: 0.577216
# [145]	valid_0's multi_error: 0.577137
# [146]	valid_0's multi_error: 0.577046
# [147]	valid_0's multi_error: 0.576955
# [148]	valid_0's multi_error: 0.576796
# [149]	valid_0's multi_error: 0.576612
# [150]	valid_0's multi_error: 0.576493
# [151]	valid_0's multi_error: 0.576443
# [152]	valid_0's multi_error: 0.576331
# [153]	valid_0's multi_error: 0.576309
# [154]	valid_0's multi_error: 0.576143
# [155]	valid_0's multi_error: 0.576013
# [156]	valid_0's multi_error: 0.575913
# [157]	valid_0's multi_error: 0.575754
# [158]	valid_0's multi_error: 0.57563
# [159]	valid_0's multi_error: 0.575549
# [160]	valid_0's multi_error: 0.575469
# [161]	valid_0's multi_error: 0.575375
# [162]	valid_0's multi_error: 0.57529
# [163]	valid_0's multi_error: 0.575248
# [164]	valid_0's multi_error: 0.57511
# [165]	valid_0's multi_error: 0.575094
# [166]	valid_0's multi_error: 0.57497
# [167]	valid_0's multi_error: 0.574827
# [168]	valid_0's multi_error: 0.574681
# [169]	valid_0's multi_error: 0.574658
# [170]	valid_0's multi_error: 0.574564
# [171]	valid_0's multi_error: 0.574454
# [172]	valid_0's multi_error: 0.574479
# [173]	valid_0's multi_error: 0.574285
# [174]	valid_0's multi_error: 0.574219
# [175]	valid_0's multi_error: 0.574091
# [176]	valid_0's multi_error: 0.574015
# [177]	valid_0's multi_error: 0.573945
# [178]	valid_0's multi_error: 0.573863
# [179]	valid_0's multi_error: 0.573715
# [180]	valid_0's multi_error: 0.573657
# [181]	valid_0's multi_error: 0.573537
# [182]	valid_0's multi_error: 0.57346
# [183]	valid_0's multi_error: 0.573375
# [184]	valid_0's multi_error: 0.573248
# [185]	valid_0's multi_error: 0.573178
# [186]	valid_0's multi_error: 0.573172
# [187]	valid_0's multi_error: 0.573112
# [188]	valid_0's multi_error: 0.573013
# [189]	valid_0's multi_error: 0.572918
# [190]	valid_0's multi_error: 0.572828
# [191]	valid_0's multi_error: 0.572754
# [192]	valid_0's multi_error: 0.57266
# [193]	valid_0's multi_error: 0.572563
# [194]	valid_0's multi_error: 0.572545
# [195]	valid_0's multi_error: 0.572542
# [196]	valid_0's multi_error: 0.572472
# [197]	valid_0's multi_error: 0.572364
# [198]	valid_0's multi_error: 0.572272
# [199]	valid_0's multi_error: 0.57223
# [200]	valid_0's multi_error: 0.572145
# [201]	valid_0's multi_error: 0.572018
# [202]	valid_0's multi_error: 0.571988
# [203]	valid_0's multi_error: 0.571813
# [204]	valid_0's multi_error: 0.571694
# [205]	valid_0's multi_error: 0.571575
# [206]	valid_0's multi_error: 0.571516
# [207]	valid_0's multi_error: 0.571484
# [208]	valid_0's multi_error: 0.571516
# [209]	valid_0's multi_error: 0.571407
# [210]	valid_0's multi_error: 0.57144
# [211]	valid_0's multi_error: 0.571354
# [212]	valid_0's multi_error: 0.571345
# [213]	valid_0's multi_error: 0.571224
# [214]	valid_0's multi_error: 0.571148
# [215]	valid_0's multi_error: 0.571178
# [216]	valid_0's multi_error: 0.571151
# [217]	valid_0's multi_error: 0.571081
# [218]	valid_0's multi_error: 0.571051
# [219]	valid_0's multi_error: 0.570921
# [220]	valid_0's multi_error: 0.570813
# [221]	valid_0's multi_error: 0.570836
# [222]	valid_0's multi_error: 0.570828
# [223]	valid_0's multi_error: 0.570716
# [224]	valid_0's multi_error: 0.57061
# [225]	valid_0's multi_error: 0.570555
# [226]	valid_0's multi_error: 0.570519
# [227]	valid_0's multi_error: 0.570427
# [228]	valid_0's multi_error: 0.570396
# [229]	valid_0's multi_error: 0.570384
# [230]	valid_0's multi_error: 0.570324
# [231]	valid_0's multi_error: 0.570272
# [232]	valid_0's multi_error: 0.570224
# [233]	valid_0's multi_error: 0.570263
# [234]	valid_0's multi_error: 0.570318
# [235]	valid_0's multi_error: 0.570201
# [236]	valid_0's multi_error: 0.570112
# [237]	valid_0's multi_error: 0.570024
# [238]	valid_0's multi_error: 0.570045
# [239]	valid_0's multi_error: 0.570001
# [240]	valid_0's multi_error: 0.569948
# [241]	valid_0's multi_error: 0.569836
# [242]	valid_0's multi_error: 0.569819
# [243]	valid_0's multi_error: 0.569715
# [244]	valid_0's multi_error: 0.569748
# [245]	valid_0's multi_error: 0.569752
# [246]	valid_0's multi_error: 0.569688
# [247]	valid_0's multi_error: 0.569588
# [248]	valid_0's multi_error: 0.569597
# [249]	valid_0's multi_error: 0.569572
# [250]	valid_0's multi_error: 0.5695
# [251]	valid_0's multi_error: 0.569458
# [252]	valid_0's multi_error: 0.569373
# [253]	valid_0's multi_error: 0.569282
# [254]	valid_0's multi_error: 0.569264
# [255]	valid_0's multi_error: 0.569234
# [256]	valid_0's multi_error: 0.569099
# [257]	valid_0's multi_error: 0.569028
# [258]	valid_0's multi_error: 0.569001
# [259]	valid_0's multi_error: 0.568936
# [260]	valid_0's multi_error: 0.568815
# [261]	valid_0's multi_error: 0.568796
# [262]	valid_0's multi_error: 0.568781
# [263]	valid_0's multi_error: 0.568706
# [264]	valid_0's multi_error: 0.568678
# [265]	valid_0's multi_error: 0.568619
# ...
# [586]	valid_0's multi_error: 0.561981
# [587]	valid_0's multi_error: 0.561955
# [588]	valid_0's multi_error: 0.562032
# [589]	valid_0's multi_error: 0.561962
# [590]	valid_0's multi_error: 0.561975
# [591]	valid_0's multi_error: 0.561965
# [592]	valid_0's multi_error: 0.561971
# [593]	valid_0's multi_error: 0.561949
# [594]	valid_0's multi_error: 0.561953
# [595]	valid_0's multi_error: 0.561946
# [596]	valid_0's multi_error: 0.561922
# [597]	valid_0's multi_error: 0.561914
# [598]	valid_0's multi_error: 0.561872
# [599]	valid_0's multi_error: 0.561838
# [600]	valid_0's multi_error: 0.561853
# [601]	valid_0's multi_error: 0.561877
# [602]	valid_0's multi_error: 0.561822
# [603]	valid_0's multi_error: 0.561814
# [604]	valid_0's multi_error: 0.561792
# [605]	valid_0's multi_error: 0.561799
# [606]	valid_0's multi_error: 0.561792
# [607]	valid_0's multi_error: 0.561783
# [608]	valid_0's multi_error: 0.561768
# [609]	valid_0's multi_error: 0.561741
# [610]	valid_0's multi_error: 0.561746
# [611]	valid_0's multi_error: 0.561717
# [612]	valid_0's multi_error: 0.561732
# [613]	valid_0's multi_error: 0.561732
# [614]	valid_0's multi_error: 0.561732
# [615]	valid_0's multi_error: 0.561672
# [616]	valid_0's multi_error: 0.561684
# [617]	valid_0's multi_error: 0.561692
# [618]	valid_0's multi_error: 0.561723
# [619]	valid_0's multi_error: 0.561737
# [620]	valid_0's multi_error: 0.561777
# [621]	valid_0's multi_error: 0.561789
# [622]	valid_0's multi_error: 0.56175
# [623]	valid_0's multi_error: 0.561738
# [624]	valid_0's multi_error: 0.56171
# [625]	valid_0's multi_error: 0.561671
# [626]	valid_0's multi_error: 0.561687
# [627]	valid_0's multi_error: 0.561656
# [628]	valid_0's multi_error: 0.561634
# [629]	valid_0's multi_error: 0.561619
# [630]	valid_0's multi_error: 0.561598
# [631]	valid_0's multi_error: 0.561631
# [632]	valid_0's multi_error: 0.561611
# [633]	valid_0's multi_error: 0.561567
# [634]	valid_0's multi_error: 0.561561
# [635]	valid_0's multi_error: 0.561586
# [636]	valid_0's multi_error: 0.561584
# [637]	valid_0's multi_error: 0.561565
# [638]	valid_0's multi_error: 0.561529
# [639]	valid_0's multi_error: 0.561519
# [640]	valid_0's multi_error: 0.561513
# [641]	valid_0's multi_error: 0.561487
# [642]	valid_0's multi_error: 0.561486
# [643]	valid_0's multi_error: 0.561441
# [644]	valid_0's multi_error: 0.561432
# [645]	valid_0's multi_error: 0.56145
# [646]	valid_0's multi_error: 0.561462
# [647]	valid_0's multi_error: 0.561504
# [648]	valid_0's multi_error: 0.561499
# [649]	valid_0's multi_error: 0.561483
# [650]	valid_0's multi_error: 0.561471
# [651]	valid_0's multi_error: 0.561489
# [652]	valid_0's multi_error: 0.561453
# [653]	valid_0's multi_error: 0.561452
# [654]	valid_0's multi_error: 0.561461
# [655]	valid_0's multi_error: 0.561464
# [656]	valid_0's multi_error: 0.561453
# [657]	valid_0's multi_error: 0.561434
# [658]	valid_0's multi_error: 0.561464
# [659]	valid_0's multi_error: 0.561413
# [660]	valid_0's multi_error: 0.561414
# [661]	valid_0's multi_error: 0.561392
# [662]	valid_0's multi_error: 0.561383
# [663]	valid_0's multi_error: 0.561356
# [664]	valid_0's multi_error: 0.561401
# [665]	valid_0's multi_error: 0.561387
# [666]	valid_0's multi_error: 0.56135
# [667]	valid_0's multi_error: 0.561334
# [668]	valid_0's multi_error: 0.561332
# [669]	valid_0's multi_error: 0.561325
# [670]	valid_0's multi_error: 0.561308
# [671]	valid_0's multi_error: 0.561289
# [672]	valid_0's multi_error: 0.561265
# [673]	valid_0's multi_error: 0.561258
# [674]	valid_0's multi_error: 0.561234
# [675]	valid_0's multi_error: 0.561228
# [676]	valid_0's multi_error: 0.561195
# [677]	valid_0's multi_error: 0.561204
# [678]	valid_0's multi_error: 0.561158
# [679]	valid_0's multi_error: 0.561183
# [680]	valid_0's multi_error: 0.561192
# [681]	valid_0's multi_error: 0.561164
# [682]	valid_0's multi_error: 0.561129
# [683]	valid_0's multi_error: 0.561135
# [684]	valid_0's multi_error: 0.561134
# [685]	valid_0's multi_error: 0.561158
# [686]	valid_0's multi_error: 0.561153
# [687]	valid_0's multi_error: 0.561149
# [688]	valid_0's multi_error: 0.561146
# [689]	valid_0's multi_error: 0.561137
# [690]	valid_0's multi_error: 0.561123
# [691]	valid_0's multi_error: 0.561128
# [692]	valid_0's multi_error: 0.561122
# [693]	valid_0's multi_error: 0.561162
# [694]	valid_0's multi_error: 0.561098
# [695]	valid_0's multi_error: 0.561095
# [696]	valid_0's multi_error: 0.561098
# [697]	valid_0's multi_error: 0.561017
# [698]	valid_0's multi_error: 0.560981
# [699]	valid_0's multi_error: 0.560969
# [700]	valid_0's multi_error: 0.560967
# [701]	valid_0's multi_error: 0.560969
# [702]	valid_0's multi_error: 0.561011
# [703]	valid_0's multi_error: 0.560998
# [704]	valid_0's multi_error: 0.560981
# [705]	valid_0's multi_error: 0.561011
# [706]	valid_0's multi_error: 0.560983
# [707]	valid_0's multi_error: 0.560986
# [708]	valid_0's multi_error: 0.560952
# [709]	valid_0's multi_error: 0.560917
# [710]	valid_0's multi_error: 0.56091
# [711]	valid_0's multi_error: 0.560907
# [712]	valid_0's multi_error: 0.560895
# [713]	valid_0's multi_error: 0.560869
# [714]	valid_0's multi_error: 0.560889
# [715]	valid_0's multi_error: 0.56084
# [716]	valid_0's multi_error: 0.560855
# [717]	valid_0's multi_error: 0.560831
# [718]	valid_0's multi_error: 0.560838
# [719]	valid_0's multi_error: 0.560841
# [720]	valid_0's multi_error: 0.560798
# [721]	valid_0's multi_error: 0.560769
# [722]	valid_0's multi_error: 0.560799
# [723]	valid_0's multi_error: 0.560829
# [724]	valid_0's multi_error: 0.560858
# [725]	valid_0's multi_error: 0.560871
# [726]	valid_0's multi_error: 0.560868
# [727]	valid_0's multi_error: 0.560865
# [728]	valid_0's multi_error: 0.560832
# [729]	valid_0's multi_error: 0.560804
# [730]	valid_0's multi_error: 0.560762
# [731]	valid_0's multi_error: 0.560769
# [732]	valid_0's multi_error: 0.560795
# [733]	valid_0's multi_error: 0.560793
# [734]	valid_0's multi_error: 0.560772
# [735]	valid_0's multi_error: 0.560771
# [736]	valid_0's multi_error: 0.560708
# [737]	valid_0's multi_error: 0.560675
# [738]	valid_0's multi_error: 0.560638
# [739]	valid_0's multi_error: 0.560595
# [740]	valid_0's multi_error: 0.560605
# [741]	valid_0's multi_error: 0.560564
# [742]	valid_0's multi_error: 0.560578
# [743]	valid_0's multi_error: 0.560586
# [744]	valid_0's multi_error: 0.560596
# [745]	valid_0's multi_error: 0.560561
# [746]	valid_0's multi_error: 0.560558
# [747]	valid_0's multi_error: 0.560578
# [748]	valid_0's multi_error: 0.560584
# [749]	valid_0's multi_error: 0.560607
# [750]	valid_0's multi_error: 0.560611
# [751]	valid_0's multi_error: 0.56059
# [752]	valid_0's multi_error: 0.560593
# [753]	valid_0's multi_error: 0.56059
# [754]	valid_0's multi_error: 0.560611
# [755]	valid_0's multi_error: 0.560598
# [756]	valid_0's multi_error: 0.560583
# [757]	valid_0's multi_error: 0.560546
# [758]	valid_0's multi_error: 0.560578
# [759]	valid_0's multi_error: 0.560611
# [760]	valid_0's multi_error: 0.560649
# [761]	valid_0's multi_error: 0.560658
# [762]	valid_0's multi_error: 0.56065
# [763]	valid_0's multi_error: 0.560662
# [764]	valid_0's multi_error: 0.560637
# [765]	valid_0's multi_error: 0.560581
# [766]	valid_0's multi_error: 0.56058
# [767]	valid_0's multi_error: 0.560589
# [768]	valid_0's multi_error: 0.560577
# [769]	valid_0's multi_error: 0.560578
# [770]	valid_0's multi_error: 0.560578
# [771]	valid_0's multi_error: 0.560581
# [772]	valid_0's multi_error: 0.560602
# [773]	valid_0's multi_error: 0.560584
# [774]	valid_0's multi_error: 0.560581
# [775]	valid_0's multi_error: 0.56055
# [776]	valid_0's multi_error: 0.560492
# [777]	valid_0's multi_error: 0.560529
# [778]	valid_0's multi_error: 0.560498
# [779]	valid_0's multi_error: 0.560474
# [780]	valid_0's multi_error: 0.560434
# [781]	valid_0's multi_error: 0.560434
# [782]	valid_0's multi_error: 0.56045
# [783]	valid_0's multi_error: 0.560465
# [784]	valid_0's multi_error: 0.560456
# [785]	valid_0's multi_error: 0.560428
# [786]	valid_0's multi_error: 0.560383
# [787]	valid_0's multi_error: 0.560374
# [788]	valid_0's multi_error: 0.560402
# [789]	valid_0's multi_error: 0.560414
# [790]	valid_0's multi_error: 0.56041
# [791]	valid_0's multi_error: 0.560387
# [792]	valid_0's multi_error: 0.56038
# [793]	valid_0's multi_error: 0.560384
# [794]	valid_0's multi_error: 0.560326
# [795]	valid_0's multi_error: 0.560343
# [796]	valid_0's multi_error: 0.560332
# [797]	valid_0's multi_error: 0.560328
# [798]	valid_0's multi_error: 0.560287
# [799]	valid_0's multi_error: 0.560308
# [800]	valid_0's multi_error: 0.560316
# [801]	valid_0's multi_error: 0.560289
# [802]	valid_0's multi_error: 0.560267
# [803]	valid_0's multi_error: 0.560256
# [804]	valid_0's multi_error: 0.560287
# [805]	valid_0's multi_error: 0.56025
# [806]	valid_0's multi_error: 0.56024
# [807]	valid_0's multi_error: 0.560262
# [808]	valid_0's multi_error: 0.560271
# [809]	valid_0's multi_error: 0.560299
# [810]	valid_0's multi_error: 0.560283
# [811]	valid_0's multi_error: 0.560208
# [812]	valid_0's multi_error: 0.56022
# [813]	valid_0's multi_error: 0.56018
# [814]	valid_0's multi_error: 0.560181
# [815]	valid_0's multi_error: 0.56019
# [816]	valid_0's multi_error: 0.560178
# [817]	valid_0's multi_error: 0.560159
# [818]	valid_0's multi_error: 0.560183
# [819]	valid_0's multi_error: 0.560214
# [820]	valid_0's multi_error: 0.560253
# [821]	valid_0's multi_error: 0.560246
# [822]	valid_0's multi_error: 0.560249
# [823]	valid_0's multi_error: 0.560275
# [824]	valid_0's multi_error: 0.560269
# [825]	valid_0's multi_error: 0.560229
# [826]	valid_0's multi_error: 0.560187
# [827]	valid_0's multi_error: 0.560193
# [828]	valid_0's multi_error: 0.560181
# [829]	valid_0's multi_error: 0.560189
# [830]	valid_0's multi_error: 0.560161
# [831]	valid_0's multi_error: 0.560135
# [832]	valid_0's multi_error: 0.560159
# [833]	valid_0's multi_error: 0.560177
# [834]	valid_0's multi_error: 0.560156
# [835]	valid_0's multi_error: 0.560189
# [836]	valid_0's multi_error: 0.560172
# [837]	valid_0's multi_error: 0.560193
# [838]	valid_0's multi_error: 0.560213
# [839]	valid_0's multi_error: 0.560211
# [840]	valid_0's multi_error: 0.560181
# [841]	valid_0's multi_error: 0.560137
# [842]	valid_0's multi_error: 0.560146
# [843]	valid_0's multi_error: 0.56014
# [844]	valid_0's multi_error: 0.560143
# [845]	valid_0's multi_error: 0.560175
# [846]	valid_0's multi_error: 0.560149
# [847]	valid_0's multi_error: 0.560105
# [848]	valid_0's multi_error: 0.56011
# [849]	valid_0's multi_error: 0.560083
# [850]	valid_0's multi_error: 0.560095
# [851]	valid_0's multi_error: 0.560074
# [852]	valid_0's multi_error: 0.560061
# [853]	valid_0's multi_error: 0.560028
# [854]	valid_0's multi_error: 0.560026
# [855]	valid_0's multi_error: 0.55998
# [856]	valid_0's multi_error: 0.559999
# [857]	valid_0's multi_error: 0.560002
# [858]	valid_0's multi_error: 0.559992
# [859]	valid_0's multi_error: 0.560034
# [860]	valid_0's multi_error: 0.560032
# [861]	valid_0's multi_error: 0.560046
# [862]	valid_0's multi_error: 0.560037
# [863]	valid_0's multi_error: 0.560046
# [864]	valid_0's multi_error: 0.560034
# [865]	valid_0's multi_error: 0.560019
# [866]	valid_0's multi_error: 0.560028
# [867]	valid_0's multi_error: 0.55998
# [868]	valid_0's multi_error: 0.559974
# [869]	valid_0's multi_error: 0.559983
# [870]	valid_0's multi_error: 0.559972
# [871]	valid_0's multi_error: 0.559947
# [872]	valid_0's multi_error: 0.559959
# [873]	valid_0's multi_error: 0.559943
# [874]	valid_0's multi_error: 0.559929
# [875]	valid_0's multi_error: 0.559928
# [876]	valid_0's multi_error: 0.559929
# [877]	valid_0's multi_error: 0.559925
# [878]	valid_0's multi_error: 0.559922
# [879]	valid_0's multi_error: 0.559886
# [880]	valid_0's multi_error: 0.559878
# [881]	valid_0's multi_error: 0.559881
# [882]	valid_0's multi_error: 0.559884
# [883]	valid_0's multi_error: 0.559884
# [884]	valid_0's multi_error: 0.55988
# [885]	valid_0's multi_error: 0.559887
# [886]	valid_0's multi_error: 0.559881
# [887]	valid_0's multi_error: 0.559862
# [888]	valid_0's multi_error: 0.559849
# [889]	valid_0's multi_error: 0.559867
# [890]	valid_0's multi_error: 0.559887
# [891]	valid_0's multi_error: 0.559864
# [892]	valid_0's multi_error: 0.559813
# [893]	valid_0's multi_error: 0.559795
# [894]	valid_0's multi_error: 0.559801
# [895]	valid_0's multi_error: 0.55982
# [896]	valid_0's multi_error: 0.559808
# [897]	valid_0's multi_error: 0.559832
# [898]	valid_0's multi_error: 0.559834
# [899]	valid_0's multi_error: 0.559835
# [900]	valid_0's multi_error: 0.559816
# [901]	valid_0's multi_error: 0.559869
# [902]	valid_0's multi_error: 0.559871
# [903]	valid_0's multi_error: 0.559869
# [904]	valid_0's multi_error: 0.559886
# [905]	valid_0's multi_error: 0.559878
# [906]	valid_0's multi_error: 0.559844
# [907]	valid_0's multi_error: 0.559861
# [908]	valid_0's multi_error: 0.559834
# [909]	valid_0's multi_error: 0.559823
# [910]	valid_0's multi_error: 0.559814
# [911]	valid_0's multi_error: 0.559811
# [912]	valid_0's multi_error: 0.559817
# [913]	valid_0's multi_error: 0.559805
# [914]	valid_0's multi_error: 0.559822
# [915]	valid_0's multi_error: 0.559834
# [916]	valid_0's multi_error: 0.559846
# [917]	valid_0's multi_error: 0.559813
# [918]	valid_0's multi_error: 0.559808
# [919]	valid_0's multi_error: 0.559822
# [920]	valid_0's multi_error: 0.559808
# [921]	valid_0's multi_error: 0.55979
# [922]	valid_0's multi_error: 0.55978
# [923]	valid_0's multi_error: 0.559762
# [924]	valid_0's multi_error: 0.559734
# [925]	valid_0's multi_error: 0.559752
# [926]	valid_0's multi_error: 0.559735
# [927]	valid_0's multi_error: 0.559747
# [928]	valid_0's multi_error: 0.55975
# [929]	valid_0's multi_error: 0.559735
# [930]	valid_0's multi_error: 0.559734
# [931]	valid_0's multi_error: 0.559764
# [932]	valid_0's multi_error: 0.559792
# [933]	valid_0's multi_error: 0.559774
# [934]	valid_0's multi_error: 0.559775
# [935]	valid_0's multi_error: 0.559781
# [936]	valid_0's multi_error: 0.55978
# [937]	valid_0's multi_error: 0.55974
# [938]	valid_0's multi_error: 0.559717
# [939]	valid_0's multi_error: 0.559687
# [940]	valid_0's multi_error: 0.559684
# [941]	valid_0's multi_error: 0.559653
# [942]	valid_0's multi_error: 0.559698
# [943]	valid_0's multi_error: 0.559714
# [944]	valid_0's multi_error: 0.559705
# [945]	valid_0's multi_error: 0.559713
# [946]	valid_0's multi_error: 0.55972
# [947]	valid_0's multi_error: 0.559741
# [948]	valid_0's multi_error: 0.559737
# [949]	valid_0's multi_error: 0.559716
# [950]	valid_0's multi_error: 0.559728
# [951]	valid_0's multi_error: 0.55975
# [952]	valid_0's multi_error: 0.559728
# [953]	valid_0's multi_error: 0.559714
# [954]	valid_0's multi_error: 0.559716
# [955]	valid_0's multi_error: 0.55972
# [956]	valid_0's multi_error: 0.559752
# [957]	valid_0's multi_error: 0.559761
# [958]	valid_0's multi_error: 0.559716
# [959]	valid_0's multi_error: 0.559711
# [960]	valid_0's multi_error: 0.559716
# [961]	valid_0's multi_error: 0.559711
# [962]	valid_0's multi_error: 0.559671
# [963]	valid_0's multi_error: 0.559686
# [964]	valid_0's multi_error: 0.559705
# [965]	valid_0's multi_error: 0.559704
# [966]	valid_0's multi_error: 0.559693
# [967]	valid_0's multi_error: 0.559704
# [968]	valid_0's multi_error: 0.559708
# [969]	valid_0's multi_error: 0.559704
# [970]	valid_0's multi_error: 0.559674
# [971]	valid_0's multi_error: 0.559681
# [972]	valid_0's multi_error: 0.559681
# [973]	valid_0's multi_error: 0.559698
# [974]	valid_0's multi_error: 0.559747
# [975]	valid_0's multi_error: 0.559675
# [976]	valid_0's multi_error: 0.559684
# [977]	valid_0's multi_error: 0.559658
# [978]	valid_0's multi_error: 0.559644
# [979]	valid_0's multi_error: 0.559635
# [980]	valid_0's multi_error: 0.559625
# [981]	valid_0's multi_error: 0.559626
# [982]	valid_0's multi_error: 0.559644
# [983]	valid_0's multi_error: 0.559626
# [984]	valid_0's multi_error: 0.559607
# [985]	valid_0's multi_error: 0.559601
# [986]	valid_0's multi_error: 0.559601
# [987]	valid_0's multi_error: 0.559564
# [988]	valid_0's multi_error: 0.559547
# [989]	valid_0's multi_error: 0.55955
# [990]	valid_0's multi_error: 0.559568
# [991]	valid_0's multi_error: 0.559586
# [992]	valid_0's multi_error: 0.559586
# [993]	valid_0's multi_error: 0.559598
# [994]	valid_0's multi_error: 0.559607
# [995]	valid_0's multi_error: 0.559565
# [996]	valid_0's multi_error: 0.559543
# [997]	valid_0's multi_error: 0.559541
# [998]	valid_0's multi_error: 0.559513
# [999]	valid_0's multi_error: 0.559514
# [1000]	valid_0's multi_error: 0.559493
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's multi_error: 0.559493
# /anaconda3/envs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:44: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
age_train['age_group'].nunique()
# Out:
# 6

# %%
history
# Out:
# import pandas as pd
# import numpy as np
# import lightgbm as lgb
# pd.set_option('display.max_columns',None)
# #读取数据
# age_train = pd.read_csv("age_train.csv", names=['uid','age_group'])
# age_test = pd.read_csv("age_test.csv", names=['uid'])
# user_basic_info = pd.read_csv("user_basic_info.csv", names=['uid','gender','city','prodName','ramCapacity','ramLeftRation','romCapacity','romLeftRation','color','fontSize','ct','carrier','os'])
# user_behavior_info = pd.read_csv("user_behavior_info.csv", names=['uid','bootTimes','AFuncTimes','BFuncTimes','CFuncTimes','DFuncTimes','EFuncTimes','FFuncTimes','FFuncSum'])
# user_app_actived = pd.read_csv("user_app_actived.csv", names=['uid','appId'])
# #user_app_usage = pd.read_csv("user_app_usage.csv")
# app_info = pd.read_csv("app_info.csv", names=['appId', 'category'])
# #处理数据量较大的user_app_usage.csv，结合app_info.csv简单统计得到appuseProcessed.csv作为特征
# def f(x):
#     s = x.value_counts()
#     return np.nan if len(s) == 0 else s.index[0]
# def processUserAppUsage():
#     resTable = pd.DataFrame()
#     reader = pd.read_csv("user_app_usage.csv", names=['uid','appId','duration','times','use_date'], iterator=True)
#     last_df = pd.DataFrame()
#
#     app_info = pd.read_csv("app_info.csv", names=['appId','category'])
#     cats = list(set(app_info['category']))
#     category2id = dict(zip(sorted(cats), range(0,len(cats))))
#     id2category = dict(zip(range(0,len(cats)), sorted(cats)))
#     app_info['category'] = app_info['category'].apply(lambda x: category2id[x])
#     i = 1
#
#     while True:
#         try:
#             print("index: {}".format(i))
#             i+=1
#             df = reader.get_chunk(1000000)
#             df = pd.concat([last_df, df])
#             idx = df.shape[0]-1
#             last_user = df.iat[idx,0]
#             while(df.iat[idx,0]==last_user):
#                 idx-=1
#             last_df = df[idx+1:]
#             df = df[:idx+1]
#
#             now_df = pd.DataFrame()
#             now_df['uid'] = df['uid'].unique()
#             now_df = now_df.merge(df.groupby('uid')['appId'].count().to_frame(), how='left', on='uid')
#             now_df = now_df.merge(df.groupby('uid')['appId','use_date'].agg(['nunique']), how='left', on='uid')
#             now_df = now_df.merge(df.groupby('uid')['duration','times'].agg(['mean','max','std']), how='left', on='uid')
#
#             now_df.columns = ['uid','usage_cnt','usage_appid_cnt','usage_date_cnt','duration_mean','duration_max','duration_std','times_mean','times_max','times_std']
#
#
#             df = df.merge(app_info, how='left', on='appId')
#             now_df = now_df.merge(df.groupby('uid')['category'].nunique().to_frame(), how='left', on='uid')
#             #print(df.groupby(['uid'])['category'].value_counts().index[0])
#             now_df['usage_most_used_category'] = df.groupby(['uid'])['category'].transform(f)
#             resTable = pd.concat([resTable, now_df])
#         except StopIteration:
#             break
#
#     resTable.to_csv("appuseProcessed.csv",index=0)
#
#     print("Iterator is stopped")
# #将user_basic_info.csv 和 user_behavior_info.csv中的字符值编码成可以训练的数值类型，合并
# class2id = {}
# id2class = {}
# def mergeBasicTables(baseTable):
#     resTable = baseTable.merge(user_basic_info, how='left', on='uid', suffixes=('_base0', '_ubaf'))
#     resTable = resTable.merge(user_behavior_info, how='left', on='uid', suffixes=('_base1', '_ubef'))
#     cat_columns = ['city','prodName','color','carrier','os','ct']
#     for c in cat_columns:
#         resTable[c] = resTable[c].apply(lambda x: x if type(x)==str else str(x))
#         sort_temp = sorted(list(set(resTable[c])))
#         class2id[c+'2id'] = dict(zip(sort_temp, range(1, len(sort_temp)+1)))
#         id2class['id2'+c] = dict(zip(range(1,len(sort_temp)+1), sort_temp))
#         resTable[c] = resTable[c].apply(lambda x: class2id[c+'2id'][x])
#
#     return resTable
# #将user_basic_info.csv 和 user_behavior_info.csv中的字符值编码成可以训练的数值类型，合并
# class2id = {}
# id2class = {}
# def mergeBasicTables(baseTable):
#     resTable = baseTable.merge(user_basic_info, how='left', on='uid', suffixes=('_base0', '_ubaf'))
#     resTable = resTable.merge(user_behavior_info, how='left', on='uid', suffixes=('_base1', '_ubef'))
#     cat_columns = ['city','prodName','color','carrier','os','ct']
#     for c in cat_columns:
#         resTable[c] = resTable[c].apply(lambda x: x if type(x)==str else str(x))
#         sort_temp = sorted(list(set(resTable[c])))
#         class2id[c+'2id'] = dict(zip(sort_temp, range(1, len(sort_temp)+1)))
#         id2class['id2'+c] = dict(zip(range(1,len(sort_temp)+1), sort_temp))
#         resTable[c] = resTable[c].apply(lambda x: class2id[c+'2id'][x])
#
#     return resTable
# #处理app使用相关数据
# #对user_app_actived.csv简单统计
# #将之前训练的appuseProcess.csv进行合并
# def mergeAppData(baseTable):
#     resTable = baseTable.merge(user_app_actived, how='left', on='uid')
#     resTable['appId'] = resTable['appId'].apply(lambda x: len(list(x.split('#'))))
#     appusedTable = pd.read_csv("appuseProcessed.csv")
#     resTable = resTable.merge(appusedTable, how='left', on='uid')
#     resTable[['category', 'usage_most_used_category']] = resTable[['category', 'usage_most_used_category']].fillna(41)
#     resTable = resTable.fillna(0)
#     #print(resTable[:5])
#     return resTable
# #合并用户基本特征以及app使用相关特征，作为训练集和测试集
# df_train = mergeAppData(mergeBasicTables(age_train))
# df_test = mergeAppData(mergeBasicTables(age_test))
# df_train.to_csv("train_data.csv", index = 0)
# print(df_train.shape)
# print(df_test.shape)
# #将user_basic_info.csv 和 user_behavior_info.csv中的字符值编码成可以训练的数值类型，合并
# class2id = {}
# id2class = {}
# processed_behavior = pd.read_csv("processed_behavior.csv", names=['uid', 'bootTimes', 'AllFuncSum', 'MaxFunc', 'FuncCnt'])
# def mergeBasicTables(baseTable):
#     resTable = baseTable.merge(user_basic_info, how='left', on='uid', suffixes=('_base0', '_ubaf'))
#     resTable = resTable.merge(processed_behavior, how='left', on='uid', suffixes=('_base1', '_ubef'))
#     cat_columns = ['city','prodName','color','carrier','os','ct']
#     for c in cat_columns:
#         resTable[c] = resTable[c].apply(lambda x: x if type(x)==str else str(x))
#         sort_temp = sorted(list(set(resTable[c])))
#         class2id[c+'2id'] = dict(zip(sort_temp, range(1, len(sort_temp)+1)))
#         id2class['id2'+c] = dict(zip(range(1,len(sort_temp)+1), sort_temp))
#         resTable[c] = resTable[c].apply(lambda x: class2id[c+'2id'][x])
#
#     return resTable
# #处理app使用相关数据
# #对user_app_actived.csv简单统计
# #将之前训练的appuseProcess.csv进行合并
# def mergeAppData(baseTable):
#     resTable = baseTable.merge(user_app_actived, how='left', on='uid')
#     resTable['appId'] = resTable['appId'].apply(lambda x: len(list(x.split('#'))))
#     appusedTable = pd.read_csv("appuseProcessed.csv")
#     resTable = resTable.merge(appusedTable, how='left', on='uid')
#     resTable[['category', 'usage_most_used_category']] = resTable[['category', 'usage_most_used_category']].fillna(41)
#     resTable = resTable.fillna(0)
#     #print(resTable[:5])
#     return resTable
# #合并用户基本特征以及app使用相关特征，作为训练集和测试集
# df_train = mergeAppData(mergeBasicTables(age_train))
# df_test = mergeAppData(mergeBasicTables(age_test))
# df_train.to_csv("train_data.csv", index = 0)
# print(df_train.shape)
# print(df_test.shape)
# #训练模型
# import os
# os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# from sklearn.feature_selection import SelectFromModel, VarianceThreshold, SelectKBest, chi2, mutual_info_classif, f_classif
# from sklearn.preprocessing import Imputer
# from sklearn.ensemble import ExtraTreesClassifier
#
# import lightgbm as lgb
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
# from sklearn.model_selection import StratifiedKFold
# print("训练模型：")
# param = {
#         'learning_rate': 0.1,
#         'lambda_l1': 0.1,
#         'lambda_l2': 0.2,
#         'max_depth': 20,
#         'objective': 'multiclass',
#         'num_class': 7,
#         'num_leaves': 31,
#         'min_data_in_leaf': 50,
#         'max_bin': 230,
#         'feature_fraction': 0.8,
#         'metric': 'multi_error'
#         }
#
# X = df_train.drop(['age_group','uid'], axis=1)
# y = df_train['age_group']
# uid = df_test['uid']
# test = df_test.drop('uid', axis=1)
#
# xx_score = []
# cv_pred = []
# skf = StratifiedKFold(n_splits=3, random_state=1030, shuffle=True)
# for index, (train_index, vali_index) in enumerate(skf.split(X, y)):
#     print(index)
#     x_train, y_train, x_vali, y_vali = np.array(X)[train_index], np.array(y)[train_index], np.array(X)[vali_index], np.array(y)[vali_index]
#     train = lgb.Dataset(x_train, y_train)
#     vali =lgb.Dataset(x_vali, y_vali)
#     print("training start...")
#     model = lgb.train(param, train, num_boost_round=1000, valid_sets=[vali], early_stopping_rounds=50)
#     xx_pred = model.predict(x_vali,num_iteration=model.best_iteration)
#     xx_pred = [np.argmax(x) for x in xx_pred]
#     xx_score.append(f1_score(y_vali,xx_pred,average='weighted'))
#     y_test = model.predict(test,num_iteration=model.best_iteration)
#     y_test = [np.argmax(x) for x in y_test]
#     if index == 0:
#         cv_pred = np.array(y_test).reshape(-1, 1)
#     else:
#         cv_pred = np.hstack((cv_pred, np.array(y_test).reshape(-1, 1)))
#
# submit = []
# for line in cv_pred:
#     submit.append(np.argmax(np.bincount(line)))
# df = pd.DataFrame({'id':uid.as_matrix(),'label':submit})
# df.to_csv('submission.csv',index=False)
# history
